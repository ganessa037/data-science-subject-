# %% [markdown]
# # **Lab 5**

# %% [markdown]
# ## Exploring Data
#
# In this lab, you will learn how to explore data from ground-up. Of course, exploratory analysis also requires appropriate data cleaning and pre-processing (transformation, etc.) to be performed either priorly or concurrently. You will also learn how to read and interpret the data in JSON files.
#
# * [I. Creating a cleaning pipeline](#sectionI)
# * [II. Applying transformations before exploring](#sectionII)
# * [III. Exploring JSON data](#sectionIII)
#
# > **Credit note:** A portion of this lab was adapted from [UC Berkeley's Principles and Techniques of Data Science (DS 100)](https://www.textbook.ds100.org/).

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.10.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Requirement already satisfied: cycler>=0.10 in d:\[1] ganessawork\degree_computer_science\2nd year 3rd sem\data-science-subject-\labs\.env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\[1] ganessawork\degree_computer_science\2nd year 3rd sem\data-science-subject-\labs\.env\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\[1] ganessawork\degree_computer_science\2nd year 3rd sem\data-science-subject-\labs\.env\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in d:\[1] ganessawork\degree_computer_science\2nd year 3rd sem\data-science-subject-\labs\.env\lib\site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in d:\[1] ganessawork\degree_computer_science\2nd year 3rd sem\data-science-subject-\labs\.env\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in d:\[1] ganessawork\degree_computer_science\2nd year 3rd sem\data-science-subject-\labs\.env\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\[1] ganessawork\degree_computer_science\2nd year 3rd sem\data-science-subject-\labs\.env\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\[1] ganessawork\degree_computer_science\2nd year 3rd sem\data-science-subject-\labs\.env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\[1] ganessawork\degree_computer_science\2nd year 3rd sem\data-science-subject-\labs\.env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.10.1-cp313-cp313-win_amd64.whl (8.1 MB)
# Downloading contourpy-1.3.2-cp313-cp313-win_amd64.whl (223 kB)
# Installing collected packages: contourpy, matplotlib
# Successfully installed contourpy-1.3.2 matplotlib-3.10.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <a id="sectionI"></a>
# ## I. Creating a cleaning pipeline
#
# We will be using the Berkeley Police Department's publicly available dataset to show how to create a cleaning pipeline.
#
# **What do the data contain?** It contains very recent data (last 180 days), of calls to the police department for non-criminal problems.
#
# **What is the structure of the data?** The data file is a CSV file.

# %%
calls = pd.read_csv('Berkeley_PD_-_Calls_for_Service.csv')

# %%
calls.head()
# Out:
#      CASENO                OFFENSE                 EVENTDT EVENTTM  \
# 0  19050601  ASSAULT/BATTERY MISD.  09/06/2019 12:00:00 AM   15:15
# 1  19068295          FRAUD/FORGERY  11/26/2019 12:00:00 AM   12:00
# 2  19092646         IDENTITY THEFT  10/14/2019 12:00:00 AM   12:25
# 3  19042662         VEHICLE STOLEN  08/03/2019 12:00:00 AM   19:00
# 4  19049612        THEFT FROM AUTO  09/04/2019 12:00:00 AM   08:00
#
#                  CVLEGEND  CVDOW                InDbDate  \
# 0                 ASSAULT      5  12/21/2019 07:00:12 AM
# 1                   FRAUD      2  12/21/2019 07:00:10 AM
# 2                   FRAUD      1  12/21/2019 07:00:10 AM
# 3     MOTOR VEHICLE THEFT      6  12/21/2019 07:00:11 AM
# 4  LARCENY - FROM VEHICLE      3  12/21/2019 07:00:12 AM
#
#                                Block_Location                     BLKADDR  \
# 0  HILLEGASS AVENUE &DERBY ST\r\nBerkeley, CA  HILLEGASS AVENUE &DERBY ST
# 1  SHATTUCK AV & TELEGRAPH AV\r\nBerkeley, CA  SHATTUCK AV & TELEGRAPH AV
# 2           RUSSELL STREET ST\r\nBerkeley, CA           RUSSELL STREET ST
# 3                    0 B DOCK\r\nBerkeley, CA                    0 B DOCK
# 4             700 FLORIDA AVE\r\nBerkeley, CA             700 FLORIDA AVE
#
#        City State
# 0  Berkeley    CA
# 1  Berkeley    CA
# 2  Berkeley    CA
# 3  Berkeley    CA
# 4  Berkeley    CA

# %% [markdown]
# Based on the output above, the resulting dataframe looks OK and well-formed since we have properly named columns and the data seems to be intact.
#
# **What are the attributes of this data?**
#
# | **Column** | **Description** | **Type**   |
# |------:|-----------:|--------|
# | CASENO | Case Number | Number |
# | OFFENSE | Offense Type | Plain Text |
# | EVENTDT | Date Event Occurred | Date & Time |
# | EVENTTM | Time Event Occurred | Plain Text |
# | CVLEGEND | Description of Event | Plain Text |
# | CVDOW | Day of Week Event Occurred | Number |
# | InDbDate | Date dataset was updated in the portal | Date & Time |
# | Block_Location | Block level address of event | Location |
# | BLKADDR | | Plain Text |
# | City | | Plain Text |
# | State | | Plain Text |

# %% [markdown]
# ### Check on missing data
#
# The first thing to do is to check for missing data. However, before starting data analysis, we must check the following questions:
#
# **Are there any missing values?** Do a simple check with pandas.

# %%
null_rows = calls.isnull()    #this does not work. Append .any(axis=1) to make it work
calls[null_rows]        # boolean indexing
# Out:
#       CASENO OFFENSE EVENTDT EVENTTM CVLEGEND  CVDOW InDbDate Block_Location  \
# 0        NaN     NaN     NaN     NaN      NaN    NaN      NaN            NaN
# 1        NaN     NaN     NaN     NaN      NaN    NaN      NaN            NaN
# 2        NaN     NaN     NaN     NaN      NaN    NaN      NaN            NaN
# 3        NaN     NaN     NaN     NaN      NaN    NaN      NaN            NaN
# 4        NaN     NaN     NaN     NaN      NaN    NaN      NaN            NaN
# ...      ...     ...     ...     ...      ...    ...      ...            ...
# 5412     NaN     NaN     NaN     NaN      NaN    NaN      NaN            NaN
# 5413     NaN     NaN     NaN     NaN      NaN    NaN      NaN            NaN
# 5414     NaN     NaN     NaN     NaN      NaN    NaN      NaN            NaN
# 5415     NaN     NaN     NaN     NaN      NaN    NaN      NaN            NaN
# 5416     NaN     NaN     NaN     NaN      NaN    NaN      NaN            NaN
#
#      BLKADDR City State
# 0        NaN  NaN   NaN
# 1        NaN  NaN   NaN
# 2        NaN  NaN   NaN
# 3        NaN  NaN   NaN
# 4        NaN  NaN   NaN
# ...      ...  ...   ...
# 5412     NaN  NaN   NaN
# 5413     NaN  NaN   NaN
# 5414     NaN  NaN   NaN
# 5415     NaN  NaN   NaN
# 5416     NaN  NaN   NaN
#
# [5417 rows x 11 columns]

# %% [markdown]
# `isnull()` applied on the whole dataframe does not produce the intended behaviour. This function needs to be applied to check for *any* NaN values along the column side (*axis=1*).

# %%
null_rows = calls.isnull().any(axis=1)    # this does not work. Append .any(axis=1) to make it work
calls[null_rows]        # boolean indexing
# Out:
#         CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 10    19092045             BURGLARY AUTO  09/24/2019 12:00:00 AM   21:00
# 58    19050808             BURGLARY AUTO  09/09/2019 12:00:00 AM   17:00
# 318   19092284             BURGLARY AUTO  10/19/2019 12:00:00 AM   02:00
# 750   19061144            VEHICLE STOLEN  10/25/2019 12:00:00 AM   19:00
# 770   19043768             FRAUD/FORGERY  08/08/2019 12:00:00 AM   17:00
# 1056  19067870      BURGLARY RESIDENTIAL  11/29/2019 12:00:00 AM   21:40
# 1173  19051242       BURGLARY COMMERCIAL  09/11/2019 12:00:00 AM   23:24
# 1329  19053006            VEHICLE STOLEN  09/19/2019 12:00:00 AM   17:00
# 1354  19067030            IDENTITY THEFT  07/16/2019 12:00:00 AM   07:17
# 1514  19063874           THEFT FROM AUTO  11/06/2019 12:00:00 AM   21:00
# 1662  19092109            IDENTITY THEFT  10/01/2019 12:00:00 AM   15:55
# 1663  19045858       BURGLARY COMMERCIAL  08/17/2019 12:00:00 AM   15:30
# 1717  19091699                 VANDALISM  08/15/2019 12:00:00 AM   23:30
# 1902  19036463                 VANDALISM  07/04/2019 12:00:00 AM   18:15
# 1991  19066725               DISTURBANCE  11/23/2019 12:00:00 AM   15:41
# 2101  19092328             BURGLARY AUTO  10/24/2019 12:00:00 AM   02:50
# 2150  19091405           THEFT FROM AUTO  07/15/2019 12:00:00 AM   22:00
# 2240  19040132      BURGLARY RESIDENTIAL  07/20/2019 12:00:00 AM   08:00
# 2368  19092087  THEFT MISD. (UNDER $950)  10/01/2019 12:00:00 AM   11:00
# 2372  19061493               DISTURBANCE  10/29/2019 12:00:00 AM   12:56
# 2383  19052158         DOMESTIC VIOLENCE  09/15/2019 12:00:00 AM   12:00
# 2441  19052127               DISTURBANCE  09/15/2019 12:00:00 AM   19:10
# 2503  19092183             BURGLARY AUTO  10/11/2019 12:00:00 AM   05:45
# 2587  19092028             BURGLARY AUTO  09/23/2019 12:00:00 AM   22:00
# 2705  19057438            VEHICLE STOLEN  10/09/2019 12:00:00 AM   20:00
# 3040  19092661  THEFT MISD. (UNDER $950)  11/29/2019 12:00:00 AM   01:50
# 3119  19038725                 VANDALISM  07/15/2019 12:00:00 AM   17:00
# 3253  19052697            VEHICLE STOLEN  09/17/2019 12:00:00 AM   16:00
# 3349  19057900            VEHICLE STOLEN  10/11/2019 12:00:00 AM   16:00
# 3520  19091295             BURGLARY AUTO  06/28/2019 12:00:00 AM   10:00
# 3541  19059696       BURGLARY COMMERCIAL  10/21/2019 12:00:00 AM   04:37
# 3670  19070349           THEFT FROM AUTO  12/11/2019 12:00:00 AM   22:15
# 4873  19092071             BURGLARY AUTO  09/30/2019 12:00:00 AM   01:50
# 4915  19036455            VEHICLE STOLEN  07/05/2019 12:00:00 AM   00:01
# 5137  19062252      BURGLARY RESIDENTIAL  11/01/2019 12:00:00 AM   18:15
# 5323  19092615      BURGLARY RESIDENTIAL  11/23/2019 12:00:00 AM   00:00
# 5324  19092033             BURGLARY AUTO  09/23/2019 12:00:00 AM   23:55
# 5329  19064707  THEFT FELONY (OVER $950)  11/11/2019 12:00:00 AM   14:00
#
#                     CVLEGEND  CVDOW                InDbDate  \
# 10        BURGLARY - VEHICLE      2  12/21/2019 07:00:08 AM
# 58        BURGLARY - VEHICLE      1  12/21/2019 07:00:12 AM
# 318       BURGLARY - VEHICLE      6  12/21/2019 07:00:09 AM
# 750      MOTOR VEHICLE THEFT      5  12/21/2019 07:00:09 AM
# 770                    FRAUD      4  12/21/2019 07:00:11 AM
# 1056  BURGLARY - RESIDENTIAL      5  12/21/2019 07:00:10 AM
# 1173   BURGLARY - COMMERCIAL      3  12/21/2019 07:00:12 AM
# 1329     MOTOR VEHICLE THEFT      4  12/21/2019 07:00:12 AM
# 1354                   FRAUD      2  12/21/2019 07:00:10 AM
# 1514  LARCENY - FROM VEHICLE      3  12/21/2019 07:00:09 AM
# 1662                   FRAUD      2  12/21/2019 07:00:08 AM
# 1663   BURGLARY - COMMERCIAL      6  12/21/2019 07:00:12 AM
# 1717               VANDALISM      4  12/21/2019 07:00:12 AM
# 1902               VANDALISM      4  12/21/2019 07:00:11 AM
# 1991      DISORDERLY CONDUCT      6  12/21/2019 07:00:10 AM
# 2101      BURGLARY - VEHICLE      4  12/21/2019 07:00:09 AM
# 2150  LARCENY - FROM VEHICLE      1  12/21/2019 07:00:11 AM
# 2240  BURGLARY - RESIDENTIAL      6  12/21/2019 07:00:11 AM
# 2368                 LARCENY      2  12/21/2019 07:00:08 AM
# 2372      DISORDERLY CONDUCT      2  12/21/2019 07:00:09 AM
# 2383          FAMILY OFFENSE      0  12/21/2019 07:00:12 AM
# 2441      DISORDERLY CONDUCT      0  12/21/2019 07:00:12 AM
# 2503      BURGLARY - VEHICLE      5  12/21/2019 07:00:09 AM
# 2587      BURGLARY - VEHICLE      1  12/21/2019 07:00:13 AM
# 2705     MOTOR VEHICLE THEFT      3  12/21/2019 07:00:08 AM
# 3040                 LARCENY      5  12/21/2019 07:00:10 AM
# 3119               VANDALISM      1  12/21/2019 07:00:11 AM
# 3253     MOTOR VEHICLE THEFT      2  12/21/2019 07:00:13 AM
# 3349     MOTOR VEHICLE THEFT      5  12/21/2019 07:00:08 AM
# 3520      BURGLARY - VEHICLE      5  12/21/2019 07:00:08 AM
# 3541   BURGLARY - COMMERCIAL      1  12/21/2019 07:00:09 AM
# 3670  LARCENY - FROM VEHICLE      3  12/21/2019 07:00:10 AM
# 4873      BURGLARY - VEHICLE      1  12/21/2019 07:00:08 AM
# 4915     MOTOR VEHICLE THEFT      5  12/21/2019 07:00:08 AM
# 5137  BURGLARY - RESIDENTIAL      5  12/21/2019 07:00:09 AM
# 5323  BURGLARY - RESIDENTIAL      6  12/21/2019 07:00:10 AM
# 5324      BURGLARY - VEHICLE      1  12/21/2019 07:00:13 AM
# 5329                 LARCENY      1  12/21/2019 07:00:09 AM
#
#                                 Block_Location BLKADDR      City State
# 10    Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 58    Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 318   Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 750   Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 770   Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 1056  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 1173  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 1329  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 1354  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 1514  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 1662  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 1663  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 1717  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 1902  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 1991  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 2101  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 2150  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 2240  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 2368  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 2372  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 2383  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 2441  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 2503  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 2587  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 2705  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 3040  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 3119  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 3253  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 3349  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 3520  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 3541  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 3670  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 4873  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 4915  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 5137  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 5323  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 5324  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA
# 5329  Berkeley, CA\r\n(37.869058, -122.270455)     NaN  Berkeley    CA

# %%
calls[null_rows].shape
# Out:
# (38, 11)

# %% [markdown]
# There are 38 entries with at least a column with NaN value. All of them have missing BLKADDR (address) values. We also observe that all of them have Berkeley, CA recorded if the actual address location is missing. So perhaps, this is not a big problem.
#
# **Any data that can be cleaned or transformed?**
#
# In addition, an inspection of the EVENTDT column shows that it has the correct dates but records 12am for all of its times. Instead, the times are in the EVENTTM column in 24 hours format.

# %%
calls.head(7)
# Out:
#      CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0  19050601     ASSAULT/BATTERY MISD.  09/06/2019 12:00:00 AM   15:15
# 1  19068295             FRAUD/FORGERY  11/26/2019 12:00:00 AM   12:00
# 2  19092646            IDENTITY THEFT  10/14/2019 12:00:00 AM   12:25
# 3  19042662            VEHICLE STOLEN  08/03/2019 12:00:00 AM   19:00
# 4  19049612           THEFT FROM AUTO  09/04/2019 12:00:00 AM   08:00
# 5  19052852             MISSING ADULT  09/19/2019 12:00:00 AM   11:27
# 6  19068080  THEFT MISD. (UNDER $950)  12/01/2019 12:00:00 AM   12:00
#
#                  CVLEGEND  CVDOW                InDbDate  \
# 0                 ASSAULT      5  12/21/2019 07:00:12 AM
# 1                   FRAUD      2  12/21/2019 07:00:10 AM
# 2                   FRAUD      1  12/21/2019 07:00:10 AM
# 3     MOTOR VEHICLE THEFT      6  12/21/2019 07:00:11 AM
# 4  LARCENY - FROM VEHICLE      3  12/21/2019 07:00:12 AM
# 5          MISSING PERSON      4  12/21/2019 07:00:12 AM
# 6                 LARCENY      0  12/21/2019 07:00:10 AM
#
#                                Block_Location                     BLKADDR  \
# 0  HILLEGASS AVENUE &DERBY ST\r\nBerkeley, CA  HILLEGASS AVENUE &DERBY ST
# 1  SHATTUCK AV & TELEGRAPH AV\r\nBerkeley, CA  SHATTUCK AV & TELEGRAPH AV
# 2           RUSSELL STREET ST\r\nBerkeley, CA           RUSSELL STREET ST
# 3                    0 B DOCK\r\nBerkeley, CA                    0 B DOCK
# 4             700 FLORIDA AVE\r\nBerkeley, CA             700 FLORIDA AVE
# 5                 0 <UNKNOWN>\r\nBerkeley, CA                 0 <UNKNOWN>
# 6             600 SHATTUCK SQ\r\nBerkeley, CA             600 SHATTUCK SQ
#
#        City State
# 0  Berkeley    CA
# 1  Berkeley    CA
# 2  Berkeley    CA
# 3  Berkeley    CA
# 4  Berkeley    CA
# 5  Berkeley    CA
# 6  Berkeley    CA

# %% [markdown]
# As a data cleaning step, we want to merge the EVENTDT and EVENTTM columns to record both date and time in a single field. This single field can take the form of a [`DateTime`](https://docs.python.org/3/library/datetime.html) type, which can be created with pandas [`.to_datetime()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html) function.

# %%
calls['EVENTDT'].str[:10] + ' ' + calls['EVENTTM']
# Out:
# 0       09/06/2019 15:15
# 1       11/26/2019 12:00
# 2       10/14/2019 12:25
# 3       08/03/2019 19:00
# 4       09/04/2019 08:00
#               ...
# 5412    09/29/2019 16:50
# 5413    09/29/2019 13:06
# 5414    12/13/2019 14:00
# 5415    11/07/2019 11:45
# 5416    07/12/2019 16:00
# Length: 5417, dtype: object

# %%
combined = pd.to_datetime(
    # Combine date and time strings
    calls['EVENTDT'].str[:10] + ' ' + calls['EVENTTM'],
    infer_datetime_format=True,
)
combined.head()
# Out:
# C:\Users\ganes\AppData\Local\Temp\ipykernel_12392\2583056495.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   combined = pd.to_datetime(
# 0   2019-09-06 15:15:00
# 1   2019-11-26 12:00:00
# 2   2019-10-14 12:25:00
# 3   2019-08-03 19:00:00
# 4   2019-09-04 08:00:00
# dtype: datetime64[ns]

# %% [markdown]
# Let's create a function to place the code that will do this merging of information. This allows the transformation (the function) to be applied to the entire dataframe.

# %%
def combine_event_datetimes(calls):
    combined = pd.to_datetime(
        # Combine date and time strings
        calls['EVENTDT'].str[:10] + ' ' + calls['EVENTTM'],
        infer_datetime_format=True,
    )
    return calls.assign(EVENTDTTM=combined)

# %% [markdown]
# Pandas `assign` function creates new columns to a dataframe. So here, we specify that a new column `EVENTDTTM` is created in `calls` dataframe using the `combined` data.

# %%
calls.pipe(combine_event_datetimes).head()   # this does not make it permanent. To do so, assign it to another new dataframe
# Out:
# C:\Users\ganes\AppData\Local\Temp\ipykernel_12392\147025609.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   combined = pd.to_datetime(
#      CASENO                OFFENSE                 EVENTDT EVENTTM  \
# 0  19050601  ASSAULT/BATTERY MISD.  09/06/2019 12:00:00 AM   15:15
# 1  19068295          FRAUD/FORGERY  11/26/2019 12:00:00 AM   12:00
# 2  19092646         IDENTITY THEFT  10/14/2019 12:00:00 AM   12:25
# 3  19042662         VEHICLE STOLEN  08/03/2019 12:00:00 AM   19:00
# 4  19049612        THEFT FROM AUTO  09/04/2019 12:00:00 AM   08:00
#
#                  CVLEGEND  CVDOW                InDbDate  \
# 0                 ASSAULT      5  12/21/2019 07:00:12 AM
# 1                   FRAUD      2  12/21/2019 07:00:10 AM
# 2                   FRAUD      1  12/21/2019 07:00:10 AM
# 3     MOTOR VEHICLE THEFT      6  12/21/2019 07:00:11 AM
# 4  LARCENY - FROM VEHICLE      3  12/21/2019 07:00:12 AM
#
#                                Block_Location                     BLKADDR  \
# 0  HILLEGASS AVENUE &DERBY ST\r\nBerkeley, CA  HILLEGASS AVENUE &DERBY ST
# 1  SHATTUCK AV & TELEGRAPH AV\r\nBerkeley, CA  SHATTUCK AV & TELEGRAPH AV
# 2           RUSSELL STREET ST\r\nBerkeley, CA           RUSSELL STREET ST
# 3                    0 B DOCK\r\nBerkeley, CA                    0 B DOCK
# 4             700 FLORIDA AVE\r\nBerkeley, CA             700 FLORIDA AVE
#
#        City State           EVENTDTTM
# 0  Berkeley    CA 2019-09-06 15:15:00
# 1  Berkeley    CA 2019-11-26 12:00:00
# 2  Berkeley    CA 2019-10-14 12:25:00
# 3  Berkeley    CA 2019-08-03 19:00:00
# 4  Berkeley    CA 2019-09-04 08:00:00

# %% [markdown]
# The [`pipe`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.pipe.html) function allows a function to be applied to the entire dataframe. Another similar kind of function, [`apply`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html#pandas.DataFrame.apply) allows a function to be applied to a specific axis of the dataframe, row-wise or column-wise.

# %% [markdown]
# **Is the data entered by a human?**
#
# It looks like most of the data columns are machine-recorded, including the date, time, day of week, and location of the event.
#
# In addition, the OFFENSE and CVLEGEND columns appear to contain consistent values. We can check the unique values in each column to see if anything was misspelled:

# %%
calls['OFFENSE'].unique()
# Out:
# array(['ASSAULT/BATTERY MISD.', 'FRAUD/FORGERY', 'IDENTITY THEFT',
#        'VEHICLE STOLEN', 'THEFT FROM AUTO', 'MISSING ADULT',
#        'THEFT MISD. (UNDER $950)', 'VANDALISM', 'ROBBERY',
#        'BURGLARY AUTO', 'NARCOTICS', 'ALCOHOL OFFENSE',
#        'BURGLARY RESIDENTIAL', 'BURGLARY COMMERCIAL',
#        'THEFT FELONY (OVER $950)', 'DISTURBANCE', 'VEHICLE RECOVERED',
#        'SEXUAL ASSAULT FEL.', 'ASSAULT/BATTERY FEL.', 'DOMESTIC VIOLENCE',
#        'GUN/WEAPON', 'ARSON', 'DISTURBANCE - NOISE', 'VICE',
#        'BRANDISHING', 'THEFT FROM PERSON', 'SEXUAL ASSAULT MISD.',
#        '2ND RESPONSE', 'KIDNAPPING', 'MISSING JUVENILE',
#        'VEHICLE CODE - DUI', 'MUNICIPAL CODE'], dtype=object)

# %%
calls['CVLEGEND'].unique()
# Out:
# array(['ASSAULT', 'FRAUD', 'MOTOR VEHICLE THEFT',
#        'LARCENY - FROM VEHICLE', 'MISSING PERSON', 'LARCENY', 'VANDALISM',
#        'ROBBERY', 'BURGLARY - VEHICLE', 'DRUG VIOLATION',
#        'LIQUOR LAW VIOLATION', 'BURGLARY - RESIDENTIAL',
#        'BURGLARY - COMMERCIAL', 'DISORDERLY CONDUCT', 'RECOVERED VEHICLE',
#        'SEX CRIME', 'FAMILY OFFENSE', 'WEAPONS OFFENSE', 'ARSON',
#        'NOISE VIOLATION', 'KIDNAPPING', 'DUI', 'ALL OTHER OFFENSES'],
#       dtype=object)

# %% [markdown]
# By checking the BLKADDR column, we find some inconsistencies -- that sometimes an address is recorded (e.g. 2500 LE CONTE AVE) but other times a cross street is recorded (e.g. ALLSTON WAY & FIFTH ST) which is not specific enough. This suggests that a human entered this data in and this column will be difficult to use for analysis. Fortunately, we can use the latitude and longitude of the event instead of the street address.

# %%
calls['BLKADDR'][[1, 5001]]
# Out:
# 1       SHATTUCK AV & TELEGRAPH AV
# 5001                1500 EUCLID AV
# Name: BLKADDR, dtype: object

# %% [markdown]
# Doing some random checks on the lattitude and longitude of the event shows that it is not entirely consistent as well. Some records contain the latitude and longitude information, some do not.

# %%
calls.loc[100:109, 'Block_Location'].values   # look at 10 records from 100 to 109. Free to change this range
# Out:
# array(['MILVIA STREET & BANCROFT WY\r\nBerkeley, CA\r\n(37.867291, -122.270245)',
#        '2800 TELEGRAPH AV\r\nBerkeley, CA\r\n(37.859309, -122.259291)',
#        '2100 SHATTUCK AV\r\nBerkeley, CA\r\n(37.871167, -122.268285)',
#        '1900 SHATTUCK AV\r\nBerkeley, CA\r\n(37.873687, -122.268616)',
#        'TREMONT STREET & ESSEX ST\r\nBerkeley, CA\r\n(37.853552, -122.268286)',
#        'SHATTUCK AVE\r\nBerkeley, CA',
#        '1400 SHATTUCK AV\r\nBerkeley, CA\r\n(37.881957, -122.269551)',
#        '1000 GILMAN ST\r\nBerkeley, CA\r\n(37.88014, -122.297498)',
#        '1800 ACTON ST\r\nBerkeley, CA\r\n(37.872563, -122.284648)',
#        'MARTIN LUTHER KING JR WY & CHANNING WY\r\nBerkeley, CA\r\n(37.865169, -122.272303)'],
#       dtype=object)

# %% [markdown]
# The `Block_Location` column seemed to contain strings that record address, latitutde and longitude. Regardless of whether it has the complete set of information or not, we can separate the latitutde and longitude, and discard the actual address which is not that valuable.
#
# Using a sample record, the following procedure performs this transformation:

# %%
z = calls['Block_Location']
z = z.str.split('\n')    # convert data to string, then split by the \n 
z.tail()                 # view last 5 for easy peek at the records that need processing
# Out:
# 5412    [1300 SAN PABLO AV\r, Berkeley, CA\r, (37.8802...
# 5413    [1200 RUSSELL ST\r, Berkeley, CA\r, (37.853864...
# 5414    [1900 GRANT ST\r, Berkeley, CA\r, (37.873017, ...
# 5415    [1500 HEARST AV\r, Berkeley, CA\r, (37.872158,...
# 5416    [2400 BONAR ST\r, Berkeley, CA\r, (37.863241, ...
# Name: Block_Location, dtype: object

# %% [markdown]
# > **Note**: This [str.split](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html) is one that belongs to pandas, not the [split](https://docs.python.org/3.8/library/stdtypes.html#str.split) function of the Python string class.

# %%
z = z.str[2]    # discard the first 3 items in the list, leaving the (lat,long) 
z.tail()
# Out:
# 5412    (37.880228, -122.295798)
# 5413    (37.853864, -122.285643)
# 5414    (37.873017, -122.275481)
# 5415    (37.872158, -122.282066)
# 5416    (37.863241, -122.286176)
# Name: Block_Location, dtype: object

# %%
# it is a string, not a tuple, so we need to remove the parentheses, split again by , and dump both into separate columns
z = z.str[1:-1].str.split(', ', expand=True)  
z.tail()
# Out:
#               0            1
# 5412  37.880228  -122.295798
# 5413  37.853864  -122.285643
# 5414  37.873017  -122.275481
# 5415  37.872158  -122.282066
# 5416  37.863241  -122.286176

# %%
# finally, to rename the column names...
z = z.rename(columns={0: "Latitude", 1: "Longitude"})
z.tail()
# Out:
#        Latitude    Longitude
# 5412  37.880228  -122.295798
# 5413  37.853864  -122.285643
# 5414  37.873017  -122.275481
# 5415  37.872158  -122.282066
# 5416  37.863241  -122.286176

# %% [markdown]
# The remaining step will be to join this two columns back to the original dataframe `calls`. Let's put this all into a function:

# %%
def split_lat_lon(calls):
    return calls.join(
        calls['Block_Location']
        # Get coords from string
        .str.split('\n').str[2]
        # Remove parens from coords
        .str[1:-1]
        # Split latitude and longitude
        .str.split(', ', expand=True)
        .rename(columns={0: 'Latitude', 1: 'Longitude'})
    )

calls.pipe(split_lat_lon).tail()
# Out:
#         CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 5412  19055171  THEFT MISD. (UNDER $950)  09/29/2019 12:00:00 AM   16:50
# 5413  19055139               DISTURBANCE  09/29/2019 12:00:00 AM   13:06
# 5414  19092811                 VANDALISM  12/13/2019 12:00:00 AM   14:00
# 5415  19092456  THEFT FELONY (OVER $950)  11/07/2019 12:00:00 AM   11:45
# 5416  19091384                 VANDALISM  07/12/2019 12:00:00 AM   16:00
#
#                 CVLEGEND  CVDOW                InDbDate  \
# 5412             LARCENY      0  12/21/2019 07:00:13 AM
# 5413  DISORDERLY CONDUCT      0  12/21/2019 07:00:13 AM
# 5414           VANDALISM      5  12/21/2019 07:00:11 AM
# 5415             LARCENY      4  12/21/2019 07:00:09 AM
# 5416           VANDALISM      5  12/21/2019 07:00:11 AM
#
#                                          Block_Location            BLKADDR  \
# 5412  1300 SAN PABLO AV\r\nBerkeley, CA\r\n(37.88022...  1300 SAN PABLO AV
# 5413  1200 RUSSELL ST\r\nBerkeley, CA\r\n(37.853864,...    1200 RUSSELL ST
# 5414  1900 GRANT ST\r\nBerkeley, CA\r\n(37.873017, -...      1900 GRANT ST
# 5415  1500 HEARST AV\r\nBerkeley, CA\r\n(37.872158, ...     1500 HEARST AV
# 5416  2400 BONAR ST\r\nBerkeley, CA\r\n(37.863241, -...      2400 BONAR ST
#
#           City State   Latitude    Longitude
# 5412  Berkeley    CA  37.880228  -122.295798
# 5413  Berkeley    CA  37.853864  -122.285643
# 5414  Berkeley    CA  37.873017  -122.275481
# 5415  Berkeley    CA  37.872158  -122.282066
# 5416  Berkeley    CA  37.863241  -122.286176

# %% [markdown]
# Hooray! It works. But what happens to entries without the lat. and long. information?

# %%
calls.pipe(split_lat_lon).head(10)
# Out:
#      CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0  19050601     ASSAULT/BATTERY MISD.  09/06/2019 12:00:00 AM   15:15
# 1  19068295             FRAUD/FORGERY  11/26/2019 12:00:00 AM   12:00
# 2  19092646            IDENTITY THEFT  10/14/2019 12:00:00 AM   12:25
# 3  19042662            VEHICLE STOLEN  08/03/2019 12:00:00 AM   19:00
# 4  19049612           THEFT FROM AUTO  09/04/2019 12:00:00 AM   08:00
# 5  19052852             MISSING ADULT  09/19/2019 12:00:00 AM   11:27
# 6  19068080  THEFT MISD. (UNDER $950)  12/01/2019 12:00:00 AM   12:00
# 7  19041310                 VANDALISM  07/29/2019 12:00:00 AM   00:30
# 8  19059779     ASSAULT/BATTERY MISD.  10/21/2019 12:00:00 AM   13:47
# 9  19057555                   ROBBERY  10/10/2019 12:00:00 AM   19:08
#
#                  CVLEGEND  CVDOW                InDbDate  \
# 0                 ASSAULT      5  12/21/2019 07:00:12 AM
# 1                   FRAUD      2  12/21/2019 07:00:10 AM
# 2                   FRAUD      1  12/21/2019 07:00:10 AM
# 3     MOTOR VEHICLE THEFT      6  12/21/2019 07:00:11 AM
# 4  LARCENY - FROM VEHICLE      3  12/21/2019 07:00:12 AM
# 5          MISSING PERSON      4  12/21/2019 07:00:12 AM
# 6                 LARCENY      0  12/21/2019 07:00:10 AM
# 7               VANDALISM      1  12/21/2019 07:00:11 AM
# 8                 ASSAULT      1  12/21/2019 07:00:09 AM
# 9                 ROBBERY      4  12/21/2019 07:00:08 AM
#
#                                       Block_Location  \
# 0         HILLEGASS AVENUE &DERBY ST\r\nBerkeley, CA
# 1         SHATTUCK AV & TELEGRAPH AV\r\nBerkeley, CA
# 2                  RUSSELL STREET ST\r\nBerkeley, CA
# 3                           0 B DOCK\r\nBerkeley, CA
# 4                    700 FLORIDA AVE\r\nBerkeley, CA
# 5                        0 <UNKNOWN>\r\nBerkeley, CA
# 6                    600 SHATTUCK SQ\r\nBerkeley, CA
# 7                   6000 CHABOLYN TE\r\nBerkeley, CA
# 8                         HEARST AVE\r\nBerkeley, CA
# 9  1900 SHATTUCK AV\r\nBerkeley, CA\r\n(37.873687...
#
#                       BLKADDR      City State   Latitude    Longitude
# 0  HILLEGASS AVENUE &DERBY ST  Berkeley    CA        NaN          NaN
# 1  SHATTUCK AV & TELEGRAPH AV  Berkeley    CA        NaN          NaN
# 2           RUSSELL STREET ST  Berkeley    CA        NaN          NaN
# 3                    0 B DOCK  Berkeley    CA        NaN          NaN
# 4             700 FLORIDA AVE  Berkeley    CA        NaN          NaN
# 5                 0 <UNKNOWN>  Berkeley    CA        NaN          NaN
# 6             600 SHATTUCK SQ  Berkeley    CA        NaN          NaN
# 7            6000 CHABOLYN TE  Berkeley    CA        NaN          NaN
# 8                  HEARST AVE  Berkeley    CA        NaN          NaN
# 9            1900 SHATTUCK AV  Berkeley    CA  37.873687  -122.268616

# %% [markdown]
# Yes, NaN as you would expect since the values are not available. Assessing the damage...

# %%
calls.pipe(split_lat_lon).isnull().any(axis=1).sum()
# Out:
# np.int64(238)

# %% [markdown]
# That's quite a lot of rows...but to put things into perspective, how many percent of the entire dataframe has this issue?

# %%
calls.pipe(split_lat_lon).isnull().any(axis=1).sum() / len(calls) * 100
# Out:
# np.float64(4.393575779952004)

# %% [markdown]
# < 5% is quite reasonable in most cases, so we can leave it as such until further processing is needed.
#
# <hr>

# %% [markdown]
# The `CVDOW` column contains a number which indicates the day of the week. E.g. 0 indicates Sunday, 1 indicates Monday, etc.
# Let's first create a mapping between the number and the day.

# %%
day_of_week = pd.DataFrame({'CVDOW':[0, 1, 2, 3, 4, 5, 6], 'Day': ['Sunday', 'Monday','Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']})
day_of_week
# Out:
#    CVDOW        Day
# 0      0     Sunday
# 1      1     Monday
# 2      2    Tuesday
# 3      3  Wednesday
# 4      4   Thursday
# 5      5     Friday
# 6      6   Saturday

# %% [markdown]
# Write another function which finds the day of the week (based on CVDOW) and merge it back to the dataframe.

# %%
def match_weekday(calls):
    return calls.merge(day_of_week, on='CVDOW')  # the 'on' takes on a column which exists on both sides

calls.pipe(match_weekday).head()
# Out:
#      CASENO                OFFENSE                 EVENTDT EVENTTM  \
# 0  19050601  ASSAULT/BATTERY MISD.  09/06/2019 12:00:00 AM   15:15
# 1  19068295          FRAUD/FORGERY  11/26/2019 12:00:00 AM   12:00
# 2  19092646         IDENTITY THEFT  10/14/2019 12:00:00 AM   12:25
# 3  19042662         VEHICLE STOLEN  08/03/2019 12:00:00 AM   19:00
# 4  19049612        THEFT FROM AUTO  09/04/2019 12:00:00 AM   08:00
#
#                  CVLEGEND  CVDOW                InDbDate  \
# 0                 ASSAULT      5  12/21/2019 07:00:12 AM
# 1                   FRAUD      2  12/21/2019 07:00:10 AM
# 2                   FRAUD      1  12/21/2019 07:00:10 AM
# 3     MOTOR VEHICLE THEFT      6  12/21/2019 07:00:11 AM
# 4  LARCENY - FROM VEHICLE      3  12/21/2019 07:00:12 AM
#
#                                Block_Location                     BLKADDR  \
# 0  HILLEGASS AVENUE &DERBY ST\r\nBerkeley, CA  HILLEGASS AVENUE &DERBY ST
# 1  SHATTUCK AV & TELEGRAPH AV\r\nBerkeley, CA  SHATTUCK AV & TELEGRAPH AV
# 2           RUSSELL STREET ST\r\nBerkeley, CA           RUSSELL STREET ST
# 3                    0 B DOCK\r\nBerkeley, CA                    0 B DOCK
# 4             700 FLORIDA AVE\r\nBerkeley, CA             700 FLORIDA AVE
#
#        City State        Day
# 0  Berkeley    CA     Friday
# 1  Berkeley    CA    Tuesday
# 2  Berkeley    CA     Monday
# 3  Berkeley    CA   Saturday
# 4  Berkeley    CA  Wednesday

# %% [markdown]
# And finally, let's write a function to drop the columns that we no longer need:

# %%
def drop_unneeded_cols(calls):
    return calls.drop(columns=['CVDOW', 'InDbDate', 'Block_Location', 'City',
                               'State', 'EVENTDT', 'EVENTTM'])

# %% [markdown]
# The reason why we have been constructing functions for all these cleaning and transformation steps, is so that we can now make this into a cleaning pipeline, which we can "pipe" the dataframe through. Imagine the data being passed from one procedure to another, until the end. The eventual output will be one that is completely cleaned and transformed.

# %%
calls_final = (calls.pipe(combine_event_datetimes)
               .pipe(split_lat_lon)
               .pipe(match_weekday)
               .pipe(drop_unneeded_cols))

calls_final
# Out:
# C:\Users\ganes\AppData\Local\Temp\ipykernel_12392\147025609.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   combined = pd.to_datetime(
#         CASENO                   OFFENSE                CVLEGEND  \
# 0     19050601     ASSAULT/BATTERY MISD.                 ASSAULT
# 1     19068295             FRAUD/FORGERY                   FRAUD
# 2     19092646            IDENTITY THEFT                   FRAUD
# 3     19042662            VEHICLE STOLEN     MOTOR VEHICLE THEFT
# 4     19049612           THEFT FROM AUTO  LARCENY - FROM VEHICLE
# ...        ...                       ...                     ...
# 5412  19055171  THEFT MISD. (UNDER $950)                 LARCENY
# 5413  19055139               DISTURBANCE      DISORDERLY CONDUCT
# 5414  19092811                 VANDALISM               VANDALISM
# 5415  19092456  THEFT FELONY (OVER $950)                 LARCENY
# 5416  19091384                 VANDALISM               VANDALISM
#
#                          BLKADDR           EVENTDTTM   Latitude    Longitude  \
# 0     HILLEGASS AVENUE &DERBY ST 2019-09-06 15:15:00        NaN          NaN
# 1     SHATTUCK AV & TELEGRAPH AV 2019-11-26 12:00:00        NaN          NaN
# 2              RUSSELL STREET ST 2019-10-14 12:25:00        NaN          NaN
# 3                       0 B DOCK 2019-08-03 19:00:00        NaN          NaN
# 4                700 FLORIDA AVE 2019-09-04 08:00:00        NaN          NaN
# ...                          ...                 ...        ...          ...
# 5412           1300 SAN PABLO AV 2019-09-29 16:50:00  37.880228  -122.295798
# 5413             1200 RUSSELL ST 2019-09-29 13:06:00  37.853864  -122.285643
# 5414               1900 GRANT ST 2019-12-13 14:00:00  37.873017  -122.275481
# 5415              1500 HEARST AV 2019-11-07 11:45:00  37.872158  -122.282066
# 5416               2400 BONAR ST 2019-07-12 16:00:00  37.863241  -122.286176
#
#             Day
# 0        Friday
# 1       Tuesday
# 2        Monday
# 3      Saturday
# 4     Wednesday
# ...         ...
# 5412     Sunday
# 5413     Sunday
# 5414     Friday
# 5415   Thursday
# 5416     Friday
#
# [5417 rows x 8 columns]

# %%
calls_final.to_csv('calls_CLEANED.csv', index=False)

# %% [markdown]
# DateTime types in Python allow easy access to attributes relating to date and time. For instance, to extract the month from the datetime value:

# %%
calls_final['EVENTDTTM'].dt.month
# Out:
# 0        9
# 1       11
# 2       10
# 3        8
# 4        9
#         ..
# 5412     9
# 5413     9
# 5414    12
# 5415    11
# 5416     7
# Name: EVENTDTTM, Length: 5417, dtype: int32

# %% [markdown]
# Other datetime properties such as `year`, `day`, `min`, `max` can also be used.
#
# You can also sort the dataframe based on datetime, from oldest to newest.

# %%
calls_final.sort_values('EVENTDTTM')
# Out:
#         CASENO                   OFFENSE            CVLEGEND  \
# 529   19035002             FRAUD/FORGERY               FRAUD
# 4687  19034420  THEFT MISD. (UNDER $950)             LARCENY
# 1444  19043154  THEFT FELONY (OVER $950)             LARCENY
# 2291  19092570  THEFT FELONY (OVER $950)             LARCENY
# 3840  19034202             BURGLARY AUTO  BURGLARY - VEHICLE
# ...        ...                       ...                 ...
# 462   19071637               DISTURBANCE  DISORDERLY CONDUCT
# 3894  19092875             BURGLARY AUTO  BURGLARY - VEHICLE
# 764   19071652             BURGLARY AUTO  BURGLARY - VEHICLE
# 2700  19071651             BURGLARY AUTO  BURGLARY - VEHICLE
# 2426  19071685  THEFT FELONY (OVER $950)             LARCENY
#
#                             BLKADDR           EVENTDTTM   Latitude  \
# 529                  1200 SPRUCE ST 2019-06-23 00:00:00  37.886086
# 4687             2800 CALIFORNIA ST 2019-06-23 00:00:00  37.857216
# 1444               2100 SHATTUCK AV 2019-06-23 00:00:00  37.871167
# 2291                  2400 RIDGE RD 2019-06-23 01:00:00  37.875865
# 3840                 2500 DURANT AV 2019-06-23 01:13:00  37.867852
# ...                             ...                 ...        ...
# 462                2200 SHATTUCK AV 2019-12-18 17:06:00  37.869363
# 3894                 1000 GILMAN ST 2019-12-18 18:30:00   37.88014
# 764               3000 TELEGRAPH AV 2019-12-18 19:05:00  37.855435
# 2700             1800 UNIVERSITY AV 2019-12-18 19:10:00  37.871246
# 2426  1600 MARTIN LUTHER KING JR WY 2019-12-18 23:00:00  37.877696
#
#         Longitude        Day
# 529   -122.266573     Sunday
# 4687  -122.277614     Sunday
# 1444  -122.268285     Sunday
# 2291  -122.261749     Sunday
# 3840  -122.258699     Sunday
# ...           ...        ...
# 462   -122.268028  Wednesday
# 3894  -122.297498  Wednesday
# 764   -122.259841  Wednesday
# 2700  -122.274991  Wednesday
# 2426  -122.273684  Wednesday
#
# [5417 rows x 8 columns]

# %% [markdown]
# **Q1**: Here are two interesting questions to explore.
# * **Are more incidences reported (called) to the police occur during weekends?**
# * **Which is the most frequently occuring offense reported to the police?**
#
# Note: You can choose to draw some plots to represent the information found that led to your answer.

# %%
weekends = calls_final[(calls_final['Day']=='Saturday')|(calls_final['Day']=='Sunday')].shape[0]
weekdays = calls_final.shape[0] - weekends
if weekend > weekdays:
    incidents = 'Yes'
else:
    incidents = 'No'

print("More incidences reported during weekends?"+incidents+',')
print('Most frequently occuring offense: '+ calls_final['OFFENSE'].value_counts().index[0])
# Out:
# More incidences reported during weekends?No,
# Most frequently occuring offense: BURGLARY AUTO

# %%
# Group by 'Day' and count incidents
incident_counts_by_day = calls_final['Day'].value_counts().sort_index()

# Separate weekend and weekday counts
weekend_days = ['Saturday', 'Sunday']
weekday_days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']

weekend_count = incident_counts_by_day[weekend_days].sum()
weekday_count = incident_counts_by_day[weekday_days].sum()

# Compare weekend vs weekday counts
print(f"Weekend Incidents: {weekend_count}")
print(f"Weekday Incidents: {weekday_count}")

if weekend_count > weekday_count:
    print("Weekend has more incidents")
else:
    print("Weekday has more incidents")
# Out:
# Weekend Incidents: 1479
# Weekday Incidents: 3938
# Weekday has more incidents

# %%
# Count occurrences of each offense
offense_counts = calls_final['OFFENSE'].value_counts()

# Find the most frequent offense
most_frequent_offense = offense_counts.idxmax()
most_frequent_count = offense_counts.max()

print(f"The most frequently occurring offense is '{most_frequent_offense}' with {most_frequent_count} incidents.")
# Out:
# The most frequently occurring offense is 'BURGLARY AUTO' with 1349 incidents.

# %% [markdown]
# <a id="sectionII"></a>
# ## II. Using graphical presentations to explore
#
# Here's an interesting dataset containing baby names (from US) from year 1880 to 1989. There's easily close to 2 million rows in this dataset! Depending on your computer, you may encounter some error opening this file in MS Excel not because of the size of the data (which is only about 32 MB) but the sheer number of rows it need to load. Loading it on pandas is really convenient and fast.

# %%
baby = pd.read_csv('babynames.csv')
baby
# Out:
#               Name Sex  Count  Year
# 0             Mary   F   7065  1880
# 1             Anna   F   2604  1880
# 2             Emma   F   2003  1880
# 3        Elizabeth   F   1939  1880
# 4           Minnie   F   1746  1880
# ...            ...  ..    ...   ...
# 1957041      Zylas   M      5  2018
# 1957042      Zyran   M      5  2018
# 1957043      Zyrie   M      5  2018
# 1957044      Zyron   M      5  2018
# 1957045      Zzyzx   M      5  2018
#
# [1957046 rows x 4 columns]

# %% [markdown]
# Now, let's say we have an interesting thought about using the last letter of a name to predict the sex of the baby. Do you think this is possible? Or does it even make sense in the first place?
#
# Since we will not be doing any kind of prediction right now, we could try and check if this makes sense: find the counts of each last letter and see how "correlated" it is with the baby's sex (male/female).
#
# Pandas Series has an `apply()` method which takes in a function and applies it to each value in the Series. It's similar the `pipe` function we saw earlier (applied to entire dataframe), but this applies to a Series or a column of a DataFrame (also a Series). Passing in a simple built-in function like `len` immediately gets us the length of each record's Name. E.g. 'Mary' has 4 letters, 'Elizabeth' has 9.

# %%
names = baby['Name']
names.apply(len)
# Out:
# 0          4
# 1          4
# 2          4
# 3          9
# 4          6
#           ..
# 1957041    5
# 1957042    5
# 1957043    5
# 1957044    5
# 1957045    5
# Name: Name, Length: 1957046, dtype: int64

# %% [markdown]
# To extract the last letter of each name, we can define our own function to pass into `apply()`:

# %%
def last_letter(string):
    return string[-1]

names.apply(last_letter)
# Out:
# 0          y
# 1          a
# 2          a
# 3          h
# 4          e
#           ..
# 1957041    s
# 1957042    n
# 1957043    e
# 1957044    n
# 1957045    x
# Name: Name, Length: 1957046, dtype: object

# %% [markdown]
# Although `apply()` is flexible, it is often faster to use the built-in string manipulation functions in pandas when dealing with text data. Pandas provides access to string manipulation functions using the .str attribute of Series.

# %%
names = baby['Name']
names.str.len()
# Out:
# 0          4
# 1          4
# 2          4
# 3          9
# 4          6
#           ..
# 1957041    5
# 1957042    5
# 1957043    5
# 1957044    5
# 1957045    5
# Name: Name, Length: 1957046, dtype: int64

# %% [markdown]
# We can even directly slice out the last letter of each name in a similar way:

# %%
names.str[-1]
# Out:
# 0          y
# 1          a
# 2          a
# 3          h
# 4          e
#           ..
# 1957041    s
# 1957042    n
# 1957043    e
# 1957044    n
# 1957045    x
# Name: Name, Length: 1957046, dtype: object

# %% [markdown]
# Let's add this last letters to a new column in our dataframe.

# %%
baby['Last'] = names.str[-1]
baby
# Out:
#               Name Sex  Count  Year Last
# 0             Mary   F   7065  1880    y
# 1             Anna   F   2604  1880    a
# 2             Emma   F   2003  1880    a
# 3        Elizabeth   F   1939  1880    h
# 4           Minnie   F   1746  1880    e
# ...            ...  ..    ...   ...  ...
# 1957041      Zylas   M      5  2018    s
# 1957042      Zyran   M      5  2018    n
# 1957043      Zyrie   M      5  2018    e
# 1957044      Zyron   M      5  2018    n
# 1957045      Zzyzx   M      5  2018    x
#
# [1957046 rows x 5 columns]

# %% [markdown]
# Next, to compute the sex distribution for each last letter, we need to group by both Last and Sex.

# %%
baby.groupby(['Last', 'Sex']).sum(numeric_only=True)
# Out:
#              Count       Year
# Last Sex
# a    F    59391880  941103979
#      M     1993271   55386008
# b    F       18544    1171599
#      M     1483673    8060364
# c    F       32585    1714707
#      M     1712648   11502830
# d    F      761320   13924449
#      M    16497557   79205369
# e    F    38039540  493693112
#      M    14974942  194990241
# f    F        2747     385303
#      M      215470    7148666
# g    F       38148    3814394
#      M      610504   11385827
# h    F     8406833  107706424
#      M     7129349   43922497
# i    F     4002255  113984159
#      M     1000546   46277842
# j    F        3817     492664
#      M       36730    3347946
# k    F       42140    3492993
#      M     5477925   32530898
# l    F     5919008   77513707
#      M    15304475  132551981
# m    F      443438    8997784
#      M     5968735   30852609
# n    F    20546619  240594888
#      M    39296015  395299611
# o    F      415970   18001693
#      M     4494466  118444608
# p    F        4703     769734
#      M      689447    4318995
# q    F         804     104549
#      M       14264    1351219
# r    F     4084123   32195648
#      M    10629517   94018888
# s    F     3751649   43269223
#      M    17602667  115727560
# t    F     2555442   24022110
#      M     9612818   46269905
# u    F       90103    4986119
#      M       95292    6728169
# v    F        5600     266507
#      M       58854    4000350
# w    F       67010    1548136
#      M     3109944    4890096
# x    F       43379    2435325
#      M      686044    5314550
# y    F    25267475  144809943
#      M    18751677  117170375
# z    F      144100    4459647
#      M      126963   10111326

# %% [markdown]
# Notice that Year is also summed up since every non-grouped column is passed into the aggregation function. To avoid this, we can select out the desired columns before calling .groupby().

# %%
# When lines get long, you can wrap the entire expression in parentheses
# and insert newlines before each method call. This way of writing codes makes it easier to read, but does the same thing
letter_dist = (
    baby[['Last', 'Sex', 'Count']]
    .groupby(['Last', 'Sex'])
    .sum()
)
letter_dist
# Out:
#              Count
# Last Sex
# a    F    59391880
#      M     1993271
# b    F       18544
#      M     1483673
# c    F       32585
#      M     1712648
# d    F      761320
#      M    16497557
# e    F    38039540
#      M    14974942
# f    F        2747
#      M      215470
# g    F       38148
#      M      610504
# h    F     8406833
#      M     7129349
# i    F     4002255
#      M     1000546
# j    F        3817
#      M       36730
# k    F       42140
#      M     5477925
# l    F     5919008
#      M    15304475
# m    F      443438
#      M     5968735
# n    F    20546619
#      M    39296015
# o    F      415970
#      M     4494466
# p    F        4703
#      M      689447
# q    F         804
#      M       14264
# r    F     4084123
#      M    10629517
# s    F     3751649
#      M    17602667
# t    F     2555442
#      M     9612818
# u    F       90103
#      M       95292
# v    F        5600
#      M       58854
# w    F       67010
#      M     3109944
# x    F       43379
#      M      686044
# y    F    25267475
#      M    18751677
# z    F      144100
#      M      126963

# %% [markdown]
# Besides having string extensions, pandas also provides built-in plotting functionality for most basic plots, including bar charts, histograms, line charts, and scatterplots. To make a plot from a DataFrame, use the [`plot`](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html) function.

# %%
# We use the figsize option to make the plot larger
letter_dist.plot(kind='barh', figsize=(10, 10))
# Out:
# <Axes: ylabel='Last,Sex'>

# %% [markdown]
# So without needing to format the dataframe properly for plotting, what we ended up with is pandas automatically create pairs of Last and Sex values and plot the bars based on the count values.
#
# Although this plot shows the distribution of letters and sexes, the male and female bars are difficult to tell apart. By looking at the pandas docs on plotting, we learn that pandas plots one group of bars for row column in the DataFrame, showing one differently colored bar for each column. In other words, if we can *pivot* the Sex values (only 2 values) into column form, thus creating 2 columns, then we can plot a group of 2 bars for each Last value. This means that a pivoted version of the letter_dist table will have the right format.

# %%
letter_pivot = pd.pivot_table(
    baby, index='Last', columns='Sex', values='Count', aggfunc='sum'
)
letter_pivot
# Out:
# Sex          F         M
# Last
# a     59391880   1993271
# b        18544   1483673
# c        32585   1712648
# d       761320  16497557
# e     38039540  14974942
# f         2747    215470
# g        38148    610504
# h      8406833   7129349
# i      4002255   1000546
# j         3817     36730
# k        42140   5477925
# l      5919008  15304475
# m       443438   5968735
# n     20546619  39296015
# o       415970   4494466
# p         4703    689447
# q          804     14264
# r      4084123  10629517
# s      3751649  17602667
# t      2555442   9612818
# u        90103     95292
# v         5600     58854
# w        67010   3109944
# x        43379    686044
# y     25267475  18751677
# z       144100    126963

# %%
letter_pivot.plot.barh(figsize=(10, 10))
# Out:
# <Axes: ylabel='Last'>

# %% [markdown]
# Notice that pandas conveniently generates a legend for us as well. (In `matplotlib` directly,  we normally have to specify if you want a legend displayed.)
#
# In terms of the chart, it may still be difficult to interpret. We plot the counts for each letter and sex which causes some bars to appear very long and others to be almost invisible. We should instead plot the proportion of male and female babies for each last letter. "Proportion" give us a sense of relative comparison between two values of a similar attribute, rather than relying on the hard value, which may be sitting on a large range.

# %%
sum_for_each_letter = letter_pivot['F'] + letter_pivot['M']

letter_pivot['F prop'] = letter_pivot['F'] / sum_for_each_letter
letter_pivot['M prop'] = letter_pivot['M'] / sum_for_each_letter
letter_pivot
# Out:
# Sex          F         M    F prop    M prop
# Last
# a     59391880   1993271  0.967528  0.032472
# b        18544   1483673  0.012344  0.987656
# c        32585   1712648  0.018671  0.981329
# d       761320  16497557  0.044112  0.955888
# e     38039540  14974942  0.717531  0.282469
# f         2747    215470  0.012588  0.987412
# g        38148    610504  0.058811  0.941189
# h      8406833   7129349  0.541113  0.458887
# i      4002255   1000546  0.800003  0.199997
# j         3817     36730  0.094138  0.905862
# k        42140   5477925  0.007634  0.992366
# l      5919008  15304475  0.278890  0.721110
# m       443438   5968735  0.069156  0.930844
# n     20546619  39296015  0.343344  0.656656
# o       415970   4494466  0.084711  0.915289
# p         4703    689447  0.006775  0.993225
# q          804     14264  0.053358  0.946642
# r      4084123  10629517  0.277574  0.722426
# s      3751649  17602667  0.175686  0.824314
# t      2555442   9612818  0.210009  0.789991
# u        90103     95292  0.486006  0.513994
# v         5600     58854  0.086884  0.913116
# w        67010   3109944  0.021093  0.978907
# x        43379    686044  0.059470  0.940530
# y     25267475  18751677  0.574011  0.425989
# z       144100    126963  0.531611  0.468389

# %% [markdown]
# Keep it mind too that we possibly want to sort the proportional values (either M or F, your choice), so that we can have them ranked in the chart. So, we can construct the plot this way:

# %%
letter_pivot[['F prop', 'M prop']].sort_values('M prop').plot.barh(figsize=(10, 10))
# Out:
# <Axes: ylabel='Last'>

# %% [markdown]
# **Observations**; We can see that almost all first names that end in 'p' are male and names that end in 'a' are female! In general, the difference between bar lengths for many letters implies that we can often make a good guess to a person's sex if we just know the last letter of their first name. On a contrary, first names that end with 'u' and 'h' are probably harder to guess the person's sex.

# %% [markdown]
# **Q2**: Re-experiment again by considering the last two letters of each baby's name, instead of the last letter. E.g. 'Sarah' is 'ah', and 'Mary' is 'ry'. This means that we are now considering a "syllable", or some unit of pronounciation, and to explore if we are able to see obvious differences between syllables that are found in Male names and Female names.

# %%
# write your code here

# %% [markdown]
# <a id="sectionIII"></a>
# ## III. Exploring JSON data
#
# So far we have been reading from relatively convenient structured formats like CSV. If we encounter semi-structured kind of data like JSON or XML, how can we read them? Fortunately, Python comes with a JSON library package that can help us load JSON files.
#
# In this section, we will be using data from Berkeley Police Department which is also made publicly available since 2015. This data records all vehicle detentions (including bicycles) and pedestrian detentions (up to 5 persons) made by the police in a number of categories. The incident number, date and time, location and disposition codes are also provided.

# %%
import json

# %%
# Note that this could cause our computer to run out of memory if the file
# is large. In this case, we've verified that the file is small enough to
# read in beforehand.
with open('stops.json') as f:
    stops_dict = json.load(f)

stops_dict.keys()
# Out:
# dict_keys(['meta', 'data'])

# %% [markdown]
# Dictionaries. Access the keys to see the values.

# %%
stops_dict['meta']
# Out:
# {'view': {'id': '6e9j-pj9p',
#   'name': 'Berkeley PD - Stop Data',
#   'attribution': 'Berkeley Police Department',
#   'averageRating': 0,
#   'category': 'Public Safety',
#   'createdAt': 1444171604,
#   'description': 'This data was extracted from the Departmentâ€™s Public Safety Server and covers the data beginning January 26, 2015.  On January 26, 2015 the department began collecting data pursuant to General Order B-4 (issued December 31, 2014).  Under that order, officers were required to provide certain data after making all vehicle detentions (including bicycles) and pedestrian detentions (up to five persons).  This data set lists stops by police in the categories of traffic, suspicious vehicle, pedestrian and bicycle stops.  Incident number, date and time, location and disposition codes are also listed in this data.\r\n\r\nAddress data has been changed from a specific address, where applicable, and listed as the block where the incident occurred.  Disposition codes were entered by officers who made the stop.  These codes included the person(s) race, gender, age (range), reason for the stop, enforcement action taken, and whether or not a search was conducted.\r\n\r\nThe officers of the Berkeley Police Department are prohibited from biased based policing, which is defined as any police-initiated action that relies on the race, ethnicity, or national origin rather than the behavior of an individual or information that leads the police to a particular individual who has been identified as being engaged in criminal activity.',
#   'displayType': 'table',
#   'downloadCount': 856,
#   'hideFromCatalog': False,
#   'hideFromDataJson': False,
#   'indexUpdatedAt': 1548643722,
#   'newBackend': True,
#   'numberOfComments': 0,
#   'oid': 28816359,
#   'provenance': 'official',
#   'publicationAppendEnabled': False,
#   'publicationDate': 1526358819,
#   'publicationGroup': 4669966,
#   'publicationStage': 'published',
#   'rowsUpdatedAt': 1566861530,
#   'rowsUpdatedBy': 'cd35-9pq2',
#   'tableId': 15200734,
#   'totalTimesRated': 0,
#   'viewCount': 5912,
#   'viewLastModified': 1566861527,
#   'viewType': 'tabular',
#   'approvals': [{'reviewedAt': 1526358819,
#     'reviewedAutomatically': True,
#     'state': 'approved',
#     'submissionId': 748167,
#     'submissionObject': 'public_audience_request',
#     'submissionOutcome': 'change_audience',
#     'submittedAt': 1526358819,
#     'workflowId': 2114,
#     'submissionDetails': {'permissionType': 'READ'},
#     'submissionOutcomeApplication': {'failureCount': 0, 'status': 'success'},
#     'submitter': {'id': 'cd35-9pq2', 'displayName': 'Police'}}],
#   'columns': [{'id': -1,
#     'name': 'sid',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':sid',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'id',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':id',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'position',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':position',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'created_at',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':created_at',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'created_meta',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':created_meta',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'updated_at',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':updated_at',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'updated_meta',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':updated_meta',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'meta',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':meta',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': 359528059,
#     'name': 'Incident Number',
#     'dataTypeName': 'text',
#     'description': 'Number of incident created by Computer Aided Dispatch (CAD) program',
#     'fieldName': 'incident_number',
#     'position': 1,
#     'renderTypeName': 'text',
#     'tableColumnId': 31875525,
#     'width': 189,
#     'cachedContents': {'largest': '2019-00041981',
#      'non_null': 48211,
#      'null': '49',
#      'top': [{'item': '2018-00061828', 'count': '2'},
#       {'item': '2019-00004159', 'count': '2'},
#       {'item': '2018-00001818', 'count': '2'},
#       {'item': '2018-00011435', 'count': '2'},
#       {'item': '2018-00061838', 'count': '2'},
#       {'item': '2019-00000616', 'count': '2'},
#       {'item': '2019-00018982', 'count': '2'},
#       {'item': '2019-00018978', 'count': '2'},
#       {'item': '2015-00004870', 'count': '1'},
#       {'item': '2015-00004904', 'count': '1'},
#       {'item': '2015-00004865', 'count': '1'},
#       {'item': '2015-00004905', 'count': '1'},
#       {'item': '2015-00004909', 'count': '1'},
#       {'item': '2015-00004911', 'count': '1'},
#       {'item': '2015-00004831', 'count': '1'},
#       {'item': '2015-00004902', 'count': '1'},
#       {'item': '2015-00004922', 'count': '1'},
#       {'item': '2015-00004887', 'count': '1'},
#       {'item': '2015-00004849', 'count': '1'},
#       {'item': '2015-00004925', 'count': '1'}],
#      'smallest': '2015-00004825',
#      'not_null': '55034',
#      'cardinality': '55026'},
#     'format': {'align': 'left'}},
#    {'id': 359528060,
#     'name': 'Call Date/Time',
#     'dataTypeName': 'calendar_date',
#     'description': 'Date and time of the incident/stop',
#     'fieldName': 'call_date_time',
#     'position': 2,
#     'renderTypeName': 'calendar_date',
#     'tableColumnId': 31875526,
#     'width': 268,
#     'cachedContents': {'largest': '2019-07-31T23:49:57.000',
#      'non_null': 48254,
#      'null': '0',
#      'top': [{'item': '2019-04-09T17:42:33.000', 'count': '4'},
#       {'item': '2018-11-03T19:45:07.000', 'count': '4'},
#       {'item': '2016-05-27T21:28:00.000', 'count': '3'},
#       {'item': '2016-03-18T21:29:00.000', 'count': '3'},
#       {'item': '2015-03-07T20:53:00.000', 'count': '2'},
#       {'item': '2016-08-11T23:22:00.000', 'count': '2'},
#       {'item': '2016-08-24T23:00:00.000', 'count': '2'},
#       {'item': '2019-07-05T21:44:57.000', 'count': '2'},
#       {'item': '2016-06-01T00:14:00.000', 'count': '2'},
#       {'item': '2016-06-04T20:25:00.000', 'count': '2'},
#       {'item': '2015-10-24T14:52:00.000', 'count': '2'},
#       {'item': '2015-03-06T20:20:00.000', 'count': '2'},
#       {'item': '2016-01-03T16:20:00.000', 'count': '2'},
#       {'item': '2016-07-24T21:35:00.000', 'count': '2'},
#       {'item': '2016-04-03T21:36:00.000', 'count': '2'},
#       {'item': '2016-07-15T23:54:00.000', 'count': '2'},
#       {'item': '2015-09-06T19:15:00.000', 'count': '2'},
#       {'item': '2016-07-01T22:26:00.000', 'count': '2'},
#       {'item': '2016-12-02T15:06:00.000', 'count': '2'},
#       {'item': '2015-02-04T12:11:00.000', 'count': '2'}],
#      'smallest': '2015-01-26T00:10:00.000',
#      'not_null': '55083',
#      'cardinality': '54699'},
#     'format': {'view': 'date_time', 'align': 'left'}},
#    {'id': 359528061,
#     'name': 'Location',
#     'dataTypeName': 'text',
#     'description': 'General location of the incident/stop',
#     'fieldName': 'location',
#     'position': 3,
#     'renderTypeName': 'text',
#     'tableColumnId': 31875527,
#     'width': 196,
#     'cachedContents': {'largest': ' YALE AVE/RUGBY AVE',
#      'non_null': 48084,
#      'null': '364',
#      'top': [{'item': '80 BLOCK BOLIVAR DR', 'count': '332'},
#       {'item': '2200 BLOCK SHATTUCK AVE', 'count': '312'},
#       {'item': '37.8693028530001~-122.272234021', 'count': '213'},
#       {'item': 'UNIVERSITY AVE / SAN PABLO AVE', 'count': '202'},
#       {'item': 'UNIVERSITY AVE / SIXTH ST', 'count': '182'},
#       {'item': ' SEVENTH ST /  POTTER ST', 'count': '172'},
#       {'item': '1900 BLOCK SHATTUCK AVE', 'count': '172'},
#       {'item': ' ASHBY AVE /  SEVENTH ST', 'count': '161'},
#       {'item': '2100 BLOCK SHATTUCK AVE', 'count': '146'},
#       {'item': '100 BLOCK SEAWALL DR', 'count': '142'},
#       {'item': 'SAN PABLO AVE / UNIVERSITY AVE', 'count': '142'},
#       {'item': ' UNIVERSITY AVE /  SAN PABLO AVE', 'count': '141'},
#       {'item': 'ASHBY AVE / SAN PABLO AVE', 'count': '136'},
#       {'item': ' SEVENTH ST /  ASHBY AVE', 'count': '133'},
#       {'item': 'ASHBY AVE / SEVENTH ST', 'count': '131'},
#       {'item': 'UNIVERSITY AVE / ACTON ST', 'count': '129'},
#       {'item': ' UNIVERSITY AVE /  SIXTH ST', 'count': '128'},
#       {'item': ' POTTER ST /  SEVENTH ST', 'count': '126'},
#       {'item': 'SHATTUCK AVE / KITTREDGE ST', 'count': '126'},
#       {'item': 'SIXTH ST / UNIVERSITY AVE', 'count': '124'}],
#      'smallest': '0 BLOCK BAN',
#      'not_null': '54719',
#      'cardinality': '10802'},
#     'format': {'align': 'left'}},
#    {'id': 359528062,
#     'name': 'Incident Type',
#     'dataTypeName': 'text',
#     'description': 'This is the occurred incident type created in the CAD program.  A code signifies a traffic stop (T), suspicious vehicle stop (1196), pedestrian stop (1194) and bicycle stop (1194B).',
#     'fieldName': 'incident_type',
#     'position': 4,
#     'renderTypeName': 'text',
#     'tableColumnId': 31875528,
#     'width': 256,
#     'cachedContents': {'largest': 'T',
#      'non_null': 48254,
#      'null': '0',
#      'top': [{'item': 'T', 'count': '40751'},
#       {'item': '1194', 'count': '7928'},
#       {'item': '1196', 'count': '3914'},
#       {'item': '1194B', 'count': '2490'}],
#      'smallest': '1194',
#      'not_null': '55083',
#      'cardinality': '4'},
#     'format': {'align': 'left'}},
#    {'id': 359528063,
#     'name': 'Dispositions',
#     'dataTypeName': 'text',
#     'description': 'Ordered in the following sequence:\n1st Character = Race, as follows:\nA (Asian) B (Black) H (Hispanic) O (Other) W (White)\n2nd Character = Gender, as follows:\nF (Female) M (Male)\n3rd Character = Age Range, as follows:\n1 (Less than 18) 2 (18-29) 3 (30-39), 4 (Greater than 40)\n4th Character = Reason, as follows:\nI (Investigation) T (Traffic) R (Reasonable Suspicion)\nK (Probation/Parole) W (Wanted)\n5th Character = Enforcement, as follows:\nA (Arrest) C (Citation) O (Other) W (Warning)\n6th Character = Car Search, as follows:\nS (Search) N (No Search)\n\nAdditional dispositions may also appear.  They are:\nP - Primary case report\nM - MDT narrative only\nAR - Arrest report only (no case report submitted)\nIN - Incident report\nFC - Field Card\nCO - Collision investigation report\nMH - Emergency Psychiatric Evaluation\nTOW - Impounded vehicle\n0 or 00000 â€“ Officer made a stop of more than five persons',
#     'fieldName': 'dispositions',
#     'position': 5,
#     'renderTypeName': 'text',
#     'tableColumnId': 31875529,
#     'width': 244,
#     'cachedContents': {'largest': 'zz do not use Assist; ',
#      'non_null': 48161,
#      'null': '113',
#      'top': [{'item': 'M', 'count': '1683'},
#       {'item': 'M; ', 'count': '933'},
#       {'item': 'WM4TCN', 'count': '875'},
#       {'item': 'M;', 'count': '782'},
#       {'item': 'WM4TCN; ', 'count': '704'},
#       {'item': 'BM4TWN', 'count': '681'},
#       {'item': 'BM2TWN', 'count': '674'},
#       {'item': 'BM4TWN; ', 'count': '630'},
#       {'item': 'WM4TWN; ', 'count': '617'},
#       {'item': 'WM4TWN', 'count': '547'},
#       {'item': 'WF4TCN', 'count': '537'},
#       {'item': 'BM2TWN; ', 'count': '528'},
#       {'item': 'WF4TCN; ', 'count': '517'},
#       {'item': 'BM4TWN;', 'count': '499'},
#       {'item': 'P', 'count': '493'},
#       {'item': 'WM2TWN', 'count': '487'},
#       {'item': 'P; ', 'count': '454'},
#       {'item': 'WM4TCN;', 'count': '452'},
#       {'item': 'WM4TWN;', 'count': '440'},
#       {'item': 'BM2TWN;', 'count': '434'}],
#      'smallest': '0',
#      'not_null': '54970',
#      'cardinality': '4534'},
#     'format': {'align': 'left'}},
#    {'id': 359528065,
#     'name': 'Location - Latitude',
#     'dataTypeName': 'number',
#     'description': 'General latitude of the call.  This data is only uploaded after January 2017',
#     'fieldName': 'latitude',
#     'position': 7,
#     'rdfProperties': 'http://www.w3.org/2003/01/geo/wgs84_pos#lat',
#     'renderTypeName': 'number',
#     'tableColumnId': 48452939,
#     'width': 100,
#     'cachedContents': {'largest': '37.900832366',
#      'non_null': 22054,
#      'average': '37.86416470568613',
#      'null': '26720',
#      'top': [{'item': '37.8515148720001', 'count': '298'},
#       {'item': '37.8510085500001', 'count': '294'},
#       {'item': '37.871555254', 'count': '268'},
#       {'item': '37.8679950200001', 'count': '246'},
#       {'item': '37.8690965960001', 'count': '241'},
#       {'item': '37.852154468', 'count': '178'},
#       {'item': '37.872151456', 'count': '166'},
#       {'item': '37.8532107497425', 'count': '143'},
#       {'item': '37.869096584', 'count': '142'},
#       {'item': '37.8664441110001', 'count': '139'},
#       {'item': '37.851008546', 'count': '136'},
#       {'item': '37.8619663980001', 'count': '131'},
#       {'item': '37.851632511', 'count': '125'},
#       {'item': '37.8684892540001', 'count': '124'},
#       {'item': '37.850058909', 'count': '116'},
#       {'item': '37.8704105630001', 'count': '115'},
#       {'item': '37.867993895', 'count': '115'},
#       {'item': '37.8543163850001', 'count': '111'},
#       {'item': '37.852140633', 'count': '109'},
#       {'item': '37.8532810940001', 'count': '109'}],
#      'smallest': '37.616572406',
#      'not_null': '28363',
#      'sum': '835056.2884192018039',
#      'cardinality': '3476'},
#     'format': {'precisionStyle': 'standard',
#      'rdf': 'http://www.w3.org/2003/01/geo/wgs84_pos#lat',
#      'noCommas': 'false',
#      'align': 'right'}},
#    {'id': 404677359,
#     'name': 'Location 1 (address)',
#     'dataTypeName': 'text',
#     'fieldName': 'location_1_address',
#     'position': 7,
#     'renderTypeName': 'text',
#     'tableColumnId': 79600279,
#     'cachedContents': {'largest': 'WOOLSEY ST / REGENT ST',
#      'non_null': '8100',
#      'null': '46983',
#      'top': [{'item': '2200 BLOCK SHATTUCK AVE', 'count': '125'},
#       {'item': '2400 BLOCK TELEGRAPH AVE', 'count': '78'},
#       {'item': 'UNIVERSITY AVE / SAN PABLO AVE', 'count': '77'},
#       {'item': '37.8693028530001~-122.272234021', 'count': '77'},
#       {'item': '2100 BLOCK SHATTUCK AVE', 'count': '74'},
#       {'item': 'UNIVERSITY AVE / SIXTH ST', 'count': '67'},
#       {'item': 'SHATTUCK AVE / KITTREDGE ST', 'count': '66'},
#       {'item': 'UNIVERSITY AVE / ACTON ST', 'count': '62'},
#       {'item': '2500 BLOCK TELEGRAPH AVE', 'count': '56'},
#       {'item': 'SAN PABLO AVE / UNIVERSITY AVE', 'count': '54'},
#       {'item': 'ASHBY AVE / SAN PABLO AVE', 'count': '46'},
#       {'item': 'UNIVERSITY AVE / SACRAMENTO ST', 'count': '45'},
#       {'item': 'UNIVERSITY AVE / BONAR ST', 'count': '42'},
#       {'item': 'CEDAR ST / ACTON ST', 'count': '41'},
#       {'item': 'SIXTH ST / UNIVERSITY AVE', 'count': '41'},
#       {'item': 'UNIVERSITY AVE / NINTH ST', 'count': '40'},
#       {'item': 'ASHBY AVE / SEVENTH ST', 'count': '40'},
#       {'item': 'CENTER ST / SHATTUCK AVE', 'count': '39'},
#       {'item': '37.8609962420001~-122.256143699', 'count': '39'},
#       {'item': 'UNIVERSITY AVE / W FRONTAGE RD', 'count': '38'}],
#      'smallest': '1000 BLOCK ALLSTON WAY',
#      'cardinality': '2303'},
#     'format': {}},
#    {'id': 359528066,
#     'name': 'Location - Longitude',
#     'dataTypeName': 'number',
#     'description': 'General longitude of the call.  This data is only uploaded after January 2017.',
#     'fieldName': 'longitude',
#     'position': 8,
#     'rdfProperties': 'http://www.w3.org/2003/01/geo/wgs84_pos#long',
#     'renderTypeName': 'number',
#     'tableColumnId': 48452945,
#     'width': 100,
#     'cachedContents': {'largest': '-121.761030941',
#      'non_null': 22054,
#      'average': '-122.2801422863971',
#      'null': '26720',
#      'top': [{'item': '-122.291270407', 'count': '298'},
#       {'item': '-122.291104034', 'count': '294'},
#       {'item': '-122.297664755', 'count': '246'},
#       {'item': '-122.292119433', 'count': '241'},
#       {'item': '-122.301146607', 'count': '201'},
#       {'item': '-122.286676764', 'count': '178'},
#       {'item': '-122.284248934', 'count': '168'},
#       {'item': '-122.268413931', 'count': '166'},
#       {'item': '-122.273001342', 'count': '157'},
#       {'item': '-122.29714472956', 'count': '143'},
#       {'item': '-122.292119436', 'count': '142'},
#       {'item': '-122.305556569', 'count': '139'},
#       {'item': '-122.268727725', 'count': '139'},
#       {'item': '-122.291104031', 'count': '136'},
#       {'item': '-122.289400879', 'count': '125'},
#       {'item': '-122.26786752', 'count': '124'},
#       {'item': '-122.27270445', 'count': '122'},
#       {'item': '-122.290783207', 'count': '116'},
#       {'item': '-122.297664386', 'count': '115'},
#       {'item': '-122.281937984', 'count': '115'}],
#      'smallest': '-122.337056283',
#      'not_null': '28363',
#      'sum': '-2696766.257984202135',
#      'cardinality': '3417'},
#     'format': {'precisionStyle': 'standard',
#      'rdf': 'http://www.w3.org/2003/01/geo/wgs84_pos#long',
#      'noCommas': 'false',
#      'align': 'right'}},
#    {'id': 404677357,
#     'name': 'Location 1 (city)',
#     'dataTypeName': 'text',
#     'fieldName': 'location_1_city',
#     'position': 8,
#     'renderTypeName': 'text',
#     'tableColumnId': 79600277,
#     'cachedContents': {'largest': 'Oakland',
#      'non_null': '7291',
#      'null': '47792',
#      'top': [{'item': 'Berkeley', 'count': '6897'},
#       {'item': 'Oakland', 'count': '334'},
#       {'item': 'Emeryville', 'count': '47'},
#       {'item': 'Albany', 'count': '12'},
#       {'item': 'C4', 'count': '1'}],
#      'smallest': 'Albany',
#      'cardinality': '5'},
#     'format': {}},
#    {'id': 404677358,
#     'name': 'Location 1 (state)',
#     'dataTypeName': 'text',
#     'fieldName': 'location_1_state',
#     'position': 9,
#     'renderTypeName': 'text',
#     'tableColumnId': 79600278,
#     'cachedContents': {'largest': 'CA',
#      'non_null': '8101',
#      'null': '46982',
#      'top': [{'item': 'CA', 'count': '8101'}],
#      'smallest': 'CA',
#      'cardinality': '1'},
#     'format': {}},
#    {'id': 404677356,
#     'name': 'Location 1 (zip)',
#     'dataTypeName': 'text',
#     'fieldName': 'location_1_zip',
#     'position': 10,
#     'renderTypeName': 'text',
#     'tableColumnId': 79600276,
#     'cachedContents': {'non_null': '0', 'null': '55083', 'cardinality': '0'},
#     'format': {}},
#    {'id': 404677362,
#     'name': 'Council Districts_uniq_prepend',
#     'dataTypeName': 'number',
#     'fieldName': ':@computed_region_b3wi_w8ix',
#     'position': 13,
#     'renderTypeName': 'number',
#     'tableColumnId': 79600282,
#     'format': {}},
#    {'id': 404677363,
#     'name': 'Council Districts_from_hg3u_n7v4',
#     'dataTypeName': 'number',
#     'fieldName': ':@computed_region_fhmw_rucx',
#     'position': 14,
#     'renderTypeName': 'number',
#     'tableColumnId': 79600283,
#     'format': {}},
#    {'id': 404677364,
#     'name': 'Council Districts_from_c8zs_8y7x',
#     'dataTypeName': 'number',
#     'fieldName': ':@computed_region_u3y2_d2ws',
#     'position': 15,
#     'renderTypeName': 'number',
#     'tableColumnId': 79600284,
#     'format': {}},
#    {'id': 404677365,
#     'name': 'Zip Codes',
#     'dataTypeName': 'number',
#     'fieldName': ':@computed_region_5s6d_2f32',
#     'position': 16,
#     'renderTypeName': 'number',
#     'tableColumnId': 79600285,
#     'format': {}},
#    {'id': 404677366,
#     'name': 'Police Beats',
#     'dataTypeName': 'number',
#     'fieldName': ':@computed_region_3ini_iehf',
#     'position': 17,
#     'renderTypeName': 'number',
#     'tableColumnId': 79600286,
#     'format': {}},
#    {'id': 404677367,
#     'name': 'Census Tracts',
#     'dataTypeName': 'number',
#     'fieldName': ':@computed_region_5bih_7r3y',
#     'position': 18,
#     'renderTypeName': 'number',
#     'tableColumnId': 79600287,
#     'format': {}},
#    {'id': 404677368,
#     'name': 'Council Districts',
#     'dataTypeName': 'number',
#     'fieldName': ':@computed_region_x3q3_gi3e',
#     'position': 19,
#     'renderTypeName': 'number',
#     'tableColumnId': 79600288,
#     'format': {}}],
#   'grants': [{'inherited': False, 'type': 'viewer', 'flags': ['public']}],
#   'metadata': {'rdfSubject': '0',
#    'jsonQuery': {'order': [{'columnFieldName': 'incident_number',
#       'ascending': True}]},
#    'attachments': [{'filename': 'ODP Upload Narrative 01-14-16.pdf',
#      'assetId': '44de7d3a-0b4c-485d-80fe-c17d3d134a9e',
#      'name': 'ODP Upload Narrative 01-14-16.pdf'}],
#    'custom_fields': {'Required fields': {'One Page Narrative': 'This data was extracted from the Departmentâ€™s Public Safety Server and covers the dates from January 26, 2015 through the most present upload of data.  On January 26, 2015 the department began collecting data pursuant to General Order B-4 (issued December 31, 2014).  Under that order, officers were required to provide certain data after making all vehicle detentions (including bicycles) and pedestrian detentions (up to five persons).  This data set lists stops by police in the categories of traffic, suspicious vehicle, pedestrian and bicycle stops.  Incident number, date and time, location and disposition codes are also listed in this data.  Address data has been changed from a specific address, where applicable, and listed as the block where the incident occurred.  Disposition codes were entered by officers who made the stop.  These codes included the person(s) race, gender, age (range), reason for the stop, enforcement action taken, and whether or not a search was conducted.  The officers of the Berkeley Police Department are prohibited from biased based policing, which is defined as any police-initiated action that relies on the race, ethnicity, or national origin rather than the behavior of an individual or information that leads the police to a particular individual who has been identified as being engaged in criminal activity.'}},
#    'rowLabel': 'N/A',
#    'availableDisplayTypes': ['table', 'fatrow', 'page'],
#    'renderTypeConfig': {'visible': {'table': True}}},
#   'owner': {'id': 'cd35-9pq2',
#    'displayName': 'Police',
#    'screenName': 'Police',
#    'type': 'interactive',
#    'userSegment': 'site_member'},
#   'query': {'orderBys': [{'ascending': True,
#      'expression': {'columnId': 359528059, 'type': 'column'}}]},
#   'rights': ['read'],
#   'tableAuthor': {'id': 'cd35-9pq2',
#    'displayName': 'Police',
#    'screenName': 'Police',
#    'type': 'interactive',
#    'userSegment': 'site_member'},
#   'tags': ['police',
#    'stop data',
#    'traffic',
#    'pedestrian',
#    'vehicle',
#    'bike',
#    'race',
#    'gender',
#    'age',
#    'reason',
#    'enforcement',
#    'search'],
#   'flags': ['default', 'restorable', 'restorePossibleForType']}}

# %% [markdown]
# Let's try make some sense of the data...

# %%
stops_dict['data']
# Out:
# [['row-xkgf-zr8a.6fpe',
#   '00000000-0000-0000-4A5A-0E740119A894',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00004289',
#   '2019-01-25T14:51:35',
#   '2100 BLOCK GRANT ST',
#   'T',
#   'AM2TWN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-6s6i~mhea-aiq2',
#   '00000000-0000-0000-2A6D-4576080468CA',
#   0,
#   1555712765,
#   None,
#   1555712773,
#   None,
#   '{ }',
#   None,
#   '2017-08-07T07:18:25',
#   ' SAC/ASHB',
#   'T',
#   'M; ',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-zquh.a2sj_q4q3',
#   '00000000-0000-0000-97BB-D07AA3099E29',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00016836',
#   '2019-03-29T21:37:10',
#   '2500 BLOCK DURANT AVE',
#   'T',
#   'BM3TCN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-q5v4.77ck_hv59',
#   '00000000-0000-0000-BD2C-2D6B160554E3',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00014752',
#   '2019-03-19T19:00:51',
#   '3000 BLOCK SHATTUCK AV',
#   'T',
#   'WM4TWN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-3vse~wvru.ac54',
#   '00000000-0000-0000-E5B3-CFD85D4C4DD3',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011794',
#   '2019-03-05T16:24:38',
#   '4TH ST/ADDISON ST',
#   'T',
#   'WF3TCN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-44wq-mtpv-z4mu',
#   '00000000-0000-0000-1DC3-6422278BBFCF',
#   0,
#   1555712765,
#   None,
#   1555712773,
#   None,
#   '{ }',
#   '2015-00006976',
#   '2015-02-04T11:50:00',
#   'DERB/WARR',
#   'T',
#   'WF4TCN',
#   None,
#   'DERB/WARR',
#   None,
#   None,
#   'CA',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-tbau.rq6e.gt7b',
#   '00000000-0000-0000-DC78-0E3F61A50353',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00014494',
#   '2019-03-18T16:05:45',
#   '80/ASHBY IN I80',
#   'T',
#   'WF4TCN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-wst5~79y4_at7a',
#   '00000000-0000-0000-B640-DCB52BF2754F',
#   0,
#   1555712765,
#   None,
#   1555712773,
#   None,
#   '{ }',
#   '2015-00013226',
#   '2015-03-05T13:21:00',
#   'UNI/6TH',
#   'T',
#   'WF4TCN',
#   None,
#   'UNI/6TH',
#   None,
#   None,
#   'CA',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-n38p.fd38.fvyz',
#   '00000000-0000-0000-D2DF-F292CDC32031',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00001332',
#   '2019-01-08T22:38:34',
#   'BELV/CEDAR',
#   'T',
#   'WM3TCN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-znkf~x7bf_m7wd',
#   '00000000-0000-0000-3286-F97811501911',
#   0,
#   1555712765,
#   None,
#   1555712773,
#   None,
#   '{ }',
#   '2015-00009659',
#   '2015-02-16T10:25:00',
#   'GILMAN/10',
#   'T',
#   'OM2TCN',
#   None,
#   'GILMAN/10',
#   None,
#   None,
#   'CA',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-4xts-36p9_2qqv',
#   '00000000-0000-0000-F877-B4FD33FC0E58',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00015493',
#   '2019-03-23T10:59:43',
#   'CHP OAKLAND',
#   '1194',
#   'M;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-wk9z.n7x7_mkmx',
#   '00000000-0000-0000-7019-EB4F9627C66A',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00005193',
#   '2019-01-30T08:45:25',
#   'DERBY ST / WARRING ST',
#   'T',
#   'WM3TCN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-s4j7_278n~u8gh',
#   '00000000-0000-0000-3A1C-AC901D8ED862',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00009144',
#   '2019-02-19T18:26:59',
#   'DWIGHT WAY/FULTON ST',
#   'T',
#   'WF3TWN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ndgh-mtya.tfmp',
#   '00000000-0000-0000-1A03-893BA51E5595',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00014336',
#   '2019-03-17T20:31:51',
#   'FRONT/UNIVERSITY AVE',
#   'T',
#   'BM4TWN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-jpyg_crbq-bca2',
#   '00000000-0000-0000-2950-CD0D3652F17E',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00005350',
#   '2019-01-30T22:17:55',
#   'GRANT AVE/ADD',
#   'T',
#   'OM4TCN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-4nme.3u36~bgz4',
#   '00000000-0000-0000-2624-F23AE64F68C2',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00014337',
#   '2019-03-17T20:35:24',
#   'PEID/BAN',
#   'T',
#   'WM4TWN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-yw9a-5n9p-t2dw',
#   '00000000-0000-0000-7E54-04B22217B0E2',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00016576',
#   '2019-03-28T18:44:01',
#   'PIEDMONT AV / HASTE ST',
#   'T',
#   'WF3TCN;',
#   '37.866825383',
#   None,
#   '-122.251747514',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-n59u.pnms_kt8y',
#   '00000000-0000-0000-8F8E-1D894DC89460',
#   0,
#   1556687429,
#   None,
#   1556687434,
#   None,
#   '{ }',
#   '2019-00012091',
#   '2019-03-07T11:41:44',
#   'UNIVERSITY AV / BONAR ST',
#   'T',
#   'M;',
#   '37.869696081',
#   None,
#   '-122.28749948',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-jbt8-jwyz.jhpj',
#   '00000000-0000-0000-A41F-C90C88FBA95F',
#   0,
#   1555712765,
#   None,
#   1555712773,
#   None,
#   '{ }',
#   '2015-00018545',
#   '2015-03-31T08:26:00',
#   'WF/UNI',
#   'T',
#   'AM3TCN',
#   None,
#   'WF/UNI',
#   None,
#   None,
#   'CA',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-rtcc-kf24~uq3v',
#   '00000000-0000-0000-BBC1-0CF6E25EA48D',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00003289',
#   '2019-01-20T00:58:33',
#   'SAN PABLO AV / 67TH ST',
#   'T',
#   'BF2TWN;',
#   '37.850098191',
#   None,
#   '-122.286015829',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-8ihv~97pi-z3px',
#   '00000000-0000-0000-68C7-A9AD15565BDB',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011928',
#   '2019-03-06T13:12:13',
#   'ADDISON ST / 6TH ST',
#   'T',
#   'BF3TCN;',
#   '37.866709924',
#   None,
#   '-122.297248679',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-92i6~rm38~jjnb',
#   '00000000-0000-0000-BB88-6C4974FC4D13',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00014771',
#   '2019-03-19T21:03:10',
#   'ASHBY AV / SAN PABLO AV',
#   'T',
#   'WM4TWN;',
#   '37.852140633',
#   None,
#   '-122.286683354',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-fr38_m27n~ahqp',
#   '00000000-0000-0000-4A9A-FA0EC739FC95',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00014235',
#   '2019-03-17T10:22:51',
#   '1500 BLOCK MARTIN LUTHER KING JR WY',
#   'T',
#   'WM2TCN;',
#   '37.879571317',
#   None,
#   '-122.27394919',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-jd79-vaqm-sztj',
#   '00000000-0000-0000-5EDD-0D6367D6AFF0',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00008005',
#   '2019-02-13T18:15:25',
#   'SAN PABLO AV / CARLETON ST',
#   'T',
#   'BM2TWN;',
#   '37.858518038',
#   None,
#   '-122.288721609',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-7xyr_itk5~vwzi',
#   '00000000-0000-0000-8243-39F87E664D40',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00012197',
#   '2019-03-07T21:28:55',
#   'DURANT AV / COLLEGE AV',
#   'T',
#   'OM3TCN;',
#   '37.868390374',
#   None,
#   '-122.254428199',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-dytb~rma2_3q6s',
#   '00000000-0000-0000-466F-3EEB2A7F48BB',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00014292',
#   '2019-03-17T15:45:38',
#   'HOLLIS ST / 64TH ST',
#   'T',
#   'HF2TCN;',
#   '37.844803887',
#   None,
#   '-122.290853813',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-yef9~kzqq.6fvi',
#   '00000000-0000-0000-A518-E605FABBA286',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00001265',
#   '2019-01-08T16:52:48',
#   'CALIFORNIA ST / ALLSTON WY',
#   'T',
#   'BF3TWN;',
#   '37.867898114',
#   None,
#   '-122.279467793',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-edpn~t83y.x97b',
#   '00000000-0000-0000-13B7-5A498B07D93D',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011271',
#   '2019-03-02T22:21:18',
#   'HEARST AV / EASTSHORE BL',
#   'T',
#   'OF2TWN;',
#   '37.868193531',
#   None,
#   '-122.303628388',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-dptz~pqiq_pxbq',
#   '00000000-0000-0000-CD82-3F1BD56E2AE2',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00006517',
#   '2019-02-05T16:56:41',
#   'GILMAN ST / 9TH ST',
#   '1194B',
#   'P;',
#   '37.880024076',
#   None,
#   '-122.298075534',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-zgxa~7abm-4bej',
#   '00000000-0000-0000-A21E-0C8692F4FAB3',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00003229',
#   '2019-01-19T20:10:30',
#   'SHATTUCK AV / UNIVERSITY AV',
#   'T',
#   'WM4TCN;',
#   '37.872151444',
#   None,
#   '-122.268413925',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-tmge~4i8q_jm55',
#   '00000000-0000-0000-6B73-1230E128B73F',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00003449',
#   '2019-01-21T00:03:51',
#   'ASHBY AV / 7TH ST',
#   'T',
#   'BM3TWN;',
#   '37.851008546',
#   None,
#   '-122.291104031',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-n3fe_9uef-aryc',
#   '00000000-0000-0000-D000-F2CA122F61B6',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00001797',
#   '2019-01-11T16:18:39',
#   'MILVIA ST / BLAKE ST',
#   'T',
#   'WF4TWN;',
#   '37.862743567',
#   None,
#   '-122.269707182',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-9zar.56zh-ruw4',
#   '00000000-0000-0000-82AD-EDDCAEB67FE8',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00005460',
#   '2019-01-31T13:07:17',
#   'DURANT AV / SHATTUCK AV',
#   '1194',
#   'WM4IWN;',
#   '37.866686775',
#   None,
#   '-122.267677303',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-pstz.7v2x_4ch7',
#   '00000000-0000-0000-68C7-65CA1FB5D197',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00008628',
#   '2019-02-16T20:58:49',
#   'MARKET ST / 61ST ST',
#   'T',
#   'BM2TWS;',
#   '37.845396355',
#   None,
#   '-122.276006413',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-jjwy_2t87.3a6n',
#   '00000000-0000-0000-FD9F-04F52F14FBCC',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00008037',
#   '2019-02-13T21:32:25',
#   'SACRAMENTO ST / DWIGHT WY',
#   'T',
#   'WM2TWN;',
#   '37.862196002',
#   None,
#   '-122.281092795',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-fi9j~r4wi.j5nk',
#   '00000000-0000-0000-94F4-3A035D163572',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00009951',
#   '2019-02-23T20:40:16',
#   'EASTSHORE HW / HARRISON ST',
#   '1196',
#   'AM2TWS;',
#   '37.880086271',
#   None,
#   '-122.307222378',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ju64-8rnn_336j',
#   '00000000-0000-0000-775A-FDFEAFF6BA26',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013208',
#   '2019-03-12T17:53:05',
#   'ACTON ST / ALLSTON WY',
#   'T',
#   'WM3TCN;',
#   '37.867084236',
#   None,
#   '-122.283890242',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ttke-ddup_ejct',
#   '00000000-0000-0000-F75A-EC75347B2923',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00003767',
#   '2019-01-22T18:48:51',
#   'BOWDITCH ST / DURANT AV',
#   'T',
#   'OM4TCN;',
#   '37.868108479',
#   None,
#   '-122.256713567',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-u2kq_6dzf.de2g',
#   '00000000-0000-0000-B755-C706E9D55E96',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00001397',
#   '2019-01-09T12:04:23',
#   'FULTON ST / BANCROFT WY',
#   'T',
#   'WF4TCN;',
#   '37.867834667',
#   None,
#   '-122.265951426',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-czm5~4jsn-296q',
#   '00000000-0000-0000-069F-B7685D213008',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00001341',
#   '2019-01-09T00:37:45',
#   'DWIGHT WY / HILLEGASS AV',
#   'T',
#   'BM4TWN;',
#   '37.865379916',
#   None,
#   '-122.256505164',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-x2zt_g76k-q2xn',
#   '00000000-0000-0000-8394-6C06005DE62E',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00009106',
#   '2019-02-19T15:21:39',
#   '1900 BLOCK SHATTUCK AVE',
#   '1194',
#   'M;',
#   '37.872621663',
#   None,
#   '-122.26878737',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-rp7a.7bvw.khu3',
#   '00000000-0000-0000-9DC4-BFDC781E933D',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00004150',
#   '2019-01-24T20:28:15',
#   'MARTIN LUTHER KING JR WY / OREGON ST',
#   'T',
#   'OM2TWN;',
#   '37.857053845',
#   None,
#   '-122.27138508',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-5tym.sfe8_5em4',
#   '00000000-0000-0000-6042-364580477A00',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00003763',
#   '2019-01-22T18:18:45',
#   'COLLEGE AV / BANCROFT WY',
#   'T',
#   'WM3TWN;',
#   '37.869293483',
#   None,
#   '-122.254605479',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-9sez.uf7m_dp8s',
#   '00000000-0000-0000-33E0-07281ADA65F0',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011673',
#   '2019-03-05T01:45:45',
#   'CHANNING WY / TELEGRAPH AV',
#   'T',
#   'BM2TWN;',
#   '37.866907993',
#   None,
#   '-122.258798701',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ys53_b7fd-hyf7',
#   '00000000-0000-0000-581A-32B2509CA3A3',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00016548',
#   '2019-03-28T16:37:40',
#   'SAN PABLO AV / VIRGINIA ST',
#   'T',
#   'BF2TCN;',
#   '37.873442553',
#   None,
#   '-122.29353081',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-hbg8~wyjw_pmvi',
#   '00000000-0000-0000-03A0-83EB879CD3BE',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00009176',
#   '2019-02-19T21:27:55',
#   'SANPA/DWIG',
#   'T',
#   'BF2TWN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-tu4z_skge_u2ed',
#   '00000000-0000-0000-A929-E577C9435CDB',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00005755',
#   '2019-02-01T22:49:00',
#   'ALLSTON WY / 8TH ST',
#   'T',
#   'AR; BM4TAN;',
#   '37.865703856',
#   None,
#   '-122.294634353',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-cdux-2r79~pfyg',
#   '00000000-0000-0000-FF72-DB8404F8B880',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00000133',
#   '2019-01-02T00:44:38',
#   'SHATTUCK AV / ASHBY AV',
#   'T',
#   'BF2TWN;',
#   '37.855300548',
#   None,
#   '-122.266493172',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-d9ad_cwqj~j3uw',
#   '00000000-0000-0000-8D66-4072DA34C80A',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00000277',
#   '2019-01-02T21:36:59',
#   '1900 BLOCK ADDISON ST',
#   'T',
#   'WF4TCN;',
#   '37.8710283',
#   None,
#   '-122.271409189',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-93a2~v52x-u3qq',
#   '00000000-0000-0000-75CE-90B329F53E0C',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011456',
#   '2019-03-03T23:08:39',
#   'SHATTUCK AV / ALLSTON WY',
#   '1194',
#   'OM2TWN;',
#   '37.869391966',
#   None,
#   '-122.267932339',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-hvmj-jepa~gwtf',
#   '00000000-0000-0000-6795-FFA9946F487D',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011090',
#   '2019-03-01T21:22:35',
#   'SACRAMENTO ST / JULIA ST',
#   'T',
#   'BM4TWN;',
#   '37.854177597',
#   None,
#   '-122.279214938',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-cn2v.uyn4_gtw5',
#   '00000000-0000-0000-030B-DBF2F63B7EBE',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00006933',
#   '2019-02-07T17:09:11',
#   'SACRAMENTO ST / TYLER ST',
#   'T',
#   'BM3TCN;',
#   '37.852391494',
#   None,
#   '-122.278804902',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ruxy~su4y.d94r',
#   '00000000-0000-0000-7CC6-42F9C34D2A66',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013552',
#   '2019-03-14T10:49:50',
#   'FOLGER AV / 7TH ST',
#   'T',
#   'OM4TCN;',
#   '37.850058907',
#   None,
#   '-122.290783198',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-b73j_wfuy~ywe3',
#   '00000000-0000-0000-AC99-C383582328DE',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00004816',
#   '2019-01-28T10:56:12',
#   'RUSSELL ST / MARTIN LUTHER KING JR WY',
#   'T',
#   'BF4TCN;',
#   '37.856133159',
#   None,
#   '-122.271281689',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-3mss.u2ua-utdr',
#   '00000000-0000-0000-C013-BCAD65EC9909',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013778',
#   '2019-03-15T11:10:58',
#   'HEARST AV / SAN PABLO AV',
#   'T',
#   'WM3TCN;',
#   '37.870415355',
#   None,
#   '-122.292551501',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-9p3n-dbta~zf6f',
#   '00000000-0000-0000-7755-5F207340A2F8',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00002802',
#   '2019-01-17T17:12:25',
#   'SACRAMENTO ST / BANCROFT WY',
#   'T',
#   'WM3TCN;',
#   '37.865823524',
#   None,
#   '-122.281476128',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-uchv~bxbw.xgqp',
#   '00000000-0000-0000-D70B-046DB1337689',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00006872',
#   '2019-02-07T11:40:01',
#   'MARTIN LUTHER KING JR WY / BANCROFT WY',
#   'T',
#   'HM3TCN;',
#   '37.866971456',
#   None,
#   '-122.272505445',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-6zbt_dsip-pd92',
#   '00000000-0000-0000-07DD-4A7C1FC27DF0',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011006',
#   '2019-03-01T13:56:55',
#   'SAN PABLO AV / HEINZ AV',
#   'T',
#   'AM4TCN;',
#   '37.854397327',
#   None,
#   '-122.287395909',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-a7ec~akq9~cie2',
#   '00000000-0000-0000-00F7-4B20C67C4C9F',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00005885',
#   '2019-02-02T14:56:45',
#   '7TH ST / ASHBY AV',
#   'T',
#   'BM3TWN;',
#   '37.851008546',
#   None,
#   '-122.291104031',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-8urw~si5m_gkyv',
#   '00000000-0000-0000-E79C-172BCF033BAC',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00005318',
#   '2019-01-30T19:12:36',
#   'HASTE ST / MILVIA ST',
#   'T',
#   'OM3TWN;',
#   '37.86455417',
#   None,
#   '-122.269904559',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-y9ym-7e82~3697',
#   '00000000-0000-0000-4C17-E2F6DDF0B3EC',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00001647',
#   '2019-01-10T19:31:59',
#   'CEDAR ST / HOLLY ST',
#   'T',
#   'WM3TCN;',
#   '37.876822943',
#   None,
#   '-122.281527195',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-n9qa_eh9r.s97c',
#   '00000000-0000-0000-A221-FF48EA242C7C',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00000306',
#   '2019-01-03T07:05:07',
#   '4TH ST / HEARST AV',
#   'T',
#   'HM3IWN;',
#   '37.868876208',
#   None,
#   '-122.300284497',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-uva2-6cne-hedn',
#   '00000000-0000-0000-02EA-CE6CD61B808A',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00012407',
#   '2019-03-08T23:03:30',
#   'MARKET ST / STANFORD AV',
#   'T',
#   'WM3TWN;',
#   '37.844357271',
#   None,
#   '-122.275146769',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-9b2e_4vw3.qwd2',
#   '00000000-0000-0000-6031-686C0F0C2F3C',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00002860',
#   '2019-01-17T22:45:19',
#   'SHATTUCK AV / HEARST AV',
#   'T',
#   '000000; HM2TCN; M;',
#   '37.873890417',
#   None,
#   '-122.268580136',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-mmc3-d9pz-7c8n',
#   '00000000-0000-0000-164C-8ED23E6279C5',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00006998',
#   '2019-02-07T23:20:25',
#   'DANA ST / BLAKE ST',
#   'T',
#   'OM2TWN;',
#   '37.863936237',
#   None,
#   '-122.260531619',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-w2m9.a54u-7x2a',
#   '00000000-0000-0000-CAED-E6E6FA9645B8',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00012231',
#   '2019-03-08T03:16:19',
#   'ASHBY AV / DOMINGO AV',
#   'T',
#   'WF3TWN;',
#   '37.858080355',
#   None,
#   '-122.243863856',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-kip9_4tvj.xfru',
#   '00000000-0000-0000-F66E-69D38CB44227',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011635',
#   '2019-03-04T20:35:38',
#   'ASHBY AVE/SAN PABLO AVE',
#   'T',
#   'OM2TCN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-abmj_urpa-mxze',
#   '00000000-0000-0000-3368-85AFF2EE3CCB',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00015631',
#   '2019-03-24T00:22:46',
#   '4TH ST / ADDISON ST',
#   '1196',
#   'M;',
#   '37.866267212',
#   None,
#   '-122.299443324',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-w94y-ft7v-z97k',
#   '00000000-0000-0000-1B36-B0CCE491FFB1',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013750',
#   '2019-03-15T08:14:14',
#   'ACTON ST / ALLSTON WY',
#   'T',
#   'WF4TWN;',
#   '37.867084236',
#   None,
#   '-122.283890242',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-jnp4.52v6~2kkw',
#   '00000000-0000-0000-B477-C51538CFCC02',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00006066',
#   '2019-02-03T14:30:55',
#   'CALIFORNIA ST / ALCATRAZ AV',
#   '1196',
#   'BF3TWN;',
#   '37.848154281',
#   None,
#   '-122.27581435',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-s5ux.fnpb~uzh2',
#   '00000000-0000-0000-50D9-E334FAE920E5',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00016917',
#   '2019-03-30T09:08:05',
#   'SHATTUCK AV / WARD ST',
#   'T',
#   'BM4IWN;',
#   '37.859344948',
#   None,
#   '-122.267381116',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-s9yw-8u8j.fgax',
#   '00000000-0000-0000-BAB9-61D04F6F1AC1',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013894',
#   '2019-03-15T19:28:13',
#   'MILVIA ST / KITTREDGE ST',
#   'T',
#   'BM2TWN;',
#   '37.868155349',
#   None,
#   '-122.270352557',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-2vdk_b4e9~2eeq',
#   '00000000-0000-0000-A047-FC038ECAA9F9',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00016223',
#   '2019-03-26T23:37:52',
#   'ASHBY AV / SAN PABLO AV',
#   'T',
#   'WM4TWN;',
#   '37.852140633',
#   None,
#   '-122.286683354',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-t3gb-rpvp.cck4',
#   '00000000-0000-0000-D9C0-75E0D4D5A3CE',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00016537',
#   '2019-03-28T16:11:29',
#   'MARTIN LUTHER KING JR WY / UNIVERSITY AV',
#   'T',
#   'HM3TCN;',
#   '37.871555254',
#   None,
#   '-122.273001332',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-wnuy-wfew.kksm',
#   '00000000-0000-0000-12E5-7A3C209FA331',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00008106',
#   '2019-02-14T10:39:45',
#   'DOMINGO AV / TUNNEL RD',
#   'T',
#   'WF4TCN;',
#   '37.858080355',
#   None,
#   '-122.243863856',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-2kg7~mnf2~ds3r',
#   '00000000-0000-0000-16E7-4E616040375E',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013336',
#   '2019-03-13T11:47:38',
#   '7TH ST / HEINZ AV',
#   'T',
#   'WF4TCN;',
#   '37.853483113',
#   None,
#   '-122.291892998',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-rt5c.vqqp_dx6h',
#   '00000000-0000-0000-36DF-853145DF741B',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00012147',
#   '2019-03-07T16:29:32',
#   'MARTIN LUTHER KING JR WY / WOOLSEY ST',
#   'T',
#   'AM3TCN;',
#   '37.851578532',
#   None,
#   '-122.270762451',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-2yqb~f562.4u8b',
#   '00000000-0000-0000-2EA0-D48185DBDDC7',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00016857',
#   '2019-03-29T23:13:12',
#   'STANFORD AV / SAN PABLO AV',
#   'T',
#   '000000; AR; P;',
#   '37.840922669',
#   None,
#   '-122.283053513',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-rdkk~rk2r.87mx',
#   '00000000-0000-0000-6025-15D93F486270',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00012176',
#   '2019-03-07T19:16:31',
#   'SHATTUCK AV / KITTREDGE ST',
#   'T',
#   'OF3TCN;',
#   '37.868489253',
#   None,
#   '-122.267867519',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-w3by~tqe7~hbn5',
#   '00000000-0000-0000-CF42-E49FFDC015C6',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00010975',
#   '2019-03-01T11:41:36',
#   'SHATTUCK/ WARD',
#   'T',
#   'BF2TWN; BM2TWN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-b7nz-idh6.k859',
#   '00000000-0000-0000-67C7-9C17083E2692',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00004060',
#   '2019-01-24T10:14:09',
#   'CEDAR ST / 6TH ST',
#   '1194B',
#   'BM4TWN;',
#   '37.874090674',
#   None,
#   '-122.299629655',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ijqb_wtc4_kuue',
#   '00000000-0000-0000-209D-EE9C750051D4',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00015831',
#   '2019-03-24T23:15:07',
#   'BANCROFT WY / SAN PABLO AV',
#   'T',
#   'BM3TCN;',
#   '37.864616558',
#   None,
#   '-122.290672068',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-grcv-jbnc~bgiu',
#   '00000000-0000-0000-A12D-E31631A14DA7',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00000349',
#   '2019-01-03T12:28:13',
#   'PARKER ST / WARRING ST',
#   'T',
#   'WF4TWN;',
#   '37.86412664',
#   None,
#   '-122.250268452',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-x5u3-tm3b.s2mv',
#   '00000000-0000-0000-F391-53C55BEC04BD',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00009302',
#   '2019-02-20T17:08:02',
#   '700 BLOCK ASHBY AVE',
#   'T',
#   'WF3TCN;',
#   '37.85019145',
#   None,
#   '-122.294512994',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-z2qg_ghk3-4mur',
#   '00000000-0000-0000-D400-887A250B5C75',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00004249',
#   '2019-01-25T11:48:15',
#   '2400 BLOCK MARTIN LUTHER KING JR WY',
#   '1194',
#   'BM2WON; IN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-2idk-jb8g.sjpe',
#   '00000000-0000-0000-9BBF-221243FCF524',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00016672',
#   '2019-03-29T10:27:20',
#   'TELEGRAPH AV / HOWE ST',
#   'T',
#   'HM3TCN;',
#   '37.857122456',
#   None,
#   '-122.259545408',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-uut6~mz2s-rte2',
#   '00000000-0000-0000-90F4-EACB36F09CAB',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00015404',
#   '2019-03-22T20:23:55',
#   'BANCROFT WY / DANA ST',
#   'T',
#   'WM3TWN;',
#   '37.868409344',
#   None,
#   '-122.261453773',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-yvrw_p7en-6c36',
#   '00000000-0000-0000-0EC4-C06C20793640',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00014946',
#   '2019-03-20T17:01:53',
#   '<UNKNOWN>',
#   'T',
#   'WM4TCN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-x9kn~xhhb.8xmd',
#   '00000000-0000-0000-ADCF-C50FB315FC25',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011785',
#   '2019-03-05T16:01:36',
#   'CLAREMONT AV / WOOLSEY ST',
#   'T',
#   'BF4TCN;',
#   '37.853976073',
#   None,
#   '-122.248601464',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-qh86~8rdc.9siw',
#   '00000000-0000-0000-3036-C77BEE0CBB5E',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00012391',
#   '2019-03-08T21:28:08',
#   'SHATTUCK AV / ADELINE ST',
#   'T',
#   'BM4TWN;',
#   '37.859344948',
#   None,
#   '-122.267381116',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ndfp.jhvg_42e7',
#   '00000000-0000-0000-619A-DDDB286129DF',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00006796',
#   '2019-02-06T22:34:36',
#   'ALLSTON WY / MARTIN LUTHER KING JR WY',
#   'T',
#   'AM2TCN;',
#   '37.868774479',
#   None,
#   '-122.27270445',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-zguu.ueid_tc37',
#   '00000000-0000-0000-9DB1-449A7CCB4D25',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00015431',
#   '2019-03-22T22:34:33',
#   '80 BLOCK BOLIVAR DR',
#   '1196',
#   'BM4IWN;',
#   '37.861966398',
#   None,
#   '-122.301146607',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-exr3~z64a-zx5s',
#   '00000000-0000-0000-7D7A-8370A50050B6',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00014839',
#   '2019-03-20T08:46:10',
#   'ADDISON ST / MARTIN LUTHER KING JR WY',
#   '1194',
#   'M;',
#   '37.870582456',
#   None,
#   '-122.272893186',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-bud8_ssvu-jeig',
#   '00000000-0000-0000-CE5A-471B6F531FBA',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00010323',
#   '2019-02-25T22:27:03',
#   'MARTIN LUTHER KING JR WY / HEARST AV',
#   'T',
#   'HM2TCN;',
#   '37.87330066',
#   None,
#   '-122.273195519',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ebmn~c79u-4x4i',
#   '00000000-0000-0000-A598-5A480B6E5645',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011378',
#   '2019-03-03T14:52:32',
#   'DERBY ST / WARRING ST',
#   'T',
#   'WF4TWN;',
#   '37.862310839',
#   None,
#   '-122.250095685',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-m3gm.ftw4-vr38',
#   '00000000-0000-0000-ED30-E1520BF697AB',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00001612',
#   '2019-01-10T16:21:33',
#   'OXFORD ST / UNIVERSITY AV',
#   'T',
#   'WM3TWN;',
#   '37.872447301',
#   None,
#   '-122.266082029',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-pj25~9scj-2j9p',
#   '00000000-0000-0000-18C9-BBE49A4A5CD5',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00016928',
#   '2019-03-30T10:22:53',
#   'OXFORD ST / CENTER ST',
#   'T',
#   'WF4TCN;',
#   '37.870584522',
#   None,
#   '-122.265883484',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ktug~r2nk-u5hj',
#   '00000000-0000-0000-9167-C5A356CC002A',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00005754',
#   '2019-02-01T22:47:21',
#   '1700 BLOCK FOURTH ST',
#   '1194B',
#   'AR;',
#   '37.677645932',
#   None,
#   '-121.773652519',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ntad_3yjd_6388',
#   '00000000-0000-0000-2368-532FED98A685',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00012642',
#   '2019-03-09T22:14:00',
#   'HASKELL ST / SAN PABLO AV',
#   'T',
#   'BM4TWN;',
#   '37.850523276',
#   None,
#   '-122.286150767',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-5xp7.x6az.5nd8',
#   '00000000-0000-0000-CC1F-C8586BD7B064',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00015285',
#   '2019-03-22T10:07:49',
#   'SAN PABLO AV / PARKER ST',
#   'T',
#   'BM3TWN;',
#   '37.859355841',
#   None,
#   '-122.288991259',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-7u6m_eiqe~6i46',
#   '00000000-0000-0000-B6EE-5730524A00BC',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00004295',
#   '2019-01-25T15:24:41',
#   'HASTE ST / COLLEGE AV',
#   'T',
#   'BF2TCN; BM2TCN;',
#   '37.866608825',
#   None,
#   '-122.254075969',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-4432-985p_t8z8',
#   '00000000-0000-0000-A0D0-6C758E8ED62D',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00006620',
#   '2019-02-06T07:48:30',
#   'CEDAR ST / MILVIA ST',
#   'T',
#   'HM3TCN;',
#   '37.878124508',
#   None,
#   '-122.271423939',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-av7b-3ic9~8wzn',
#   '00000000-0000-0000-7365-7F9F45017D9D',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00003275',
#   '2019-01-19T23:48:15',
#   'KAINS AV / CAMELIA ST',
#   'T',
#   'AR;',
#   '37.878919908',
#   None,
#   '-122.294326891',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ncne.qtr6.hf94',
#   '00000000-0000-0000-D586-258E103740DA',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00014683',
#   '2019-03-19T13:42:01',
#   '7TH ST / ASHBY AV',
#   'T',
#   'HM4TCN;',
#   '37.851008546',
#   None,
#   '-122.291104031',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-k35u_vweh-wm4t',
#   '00000000-0000-0000-3069-EFFF8D79D5DE',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00012058',
#   '2019-03-07T09:13:52',
#   '4TH ST / JONES ST',
#   'T',
#   'AM4TCN;',
#   '37.874819313',
#   None,
#   '-122.302192559',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-bnse-vxcn-h9dk',
#   '00000000-0000-0000-88B7-AACF31B1B653',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011275',
#   '2019-03-02T22:44:25',
#   'SAN PABLO AV / HARRISON ST',
#   'T',
#   'WF4TWN;',
#   '37.882260272',
#   None,
#   '-122.296386552',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-vt74~fi23~iruy',
#   '00000000-0000-0000-06D4-20D32AB7FEE7',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013240',
#   '2019-03-12T21:35:45',
#   'SHATTUCK AV / CARLETON ST',
#   'T',
#   'AM2TWN;',
#   '37.861250033',
#   None,
#   '-122.267047133',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-yxrx~9t74~uq5w',
#   '00000000-0000-0000-BECF-93BDFDE76D3E',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00007461',
#   '2019-02-10T17:36:20',
#   'MC GEE AV / DELAWARE ST',
#   '1196',
#   'M;',
#   '37.873607595',
#   None,
#   '-122.277808076',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-f639~4adi.hkvu',
#   '00000000-0000-0000-06E1-AB1312B13048',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00015761',
#   '2019-03-24T16:39:42',
#   'COLLEGE AV / DWIGHT WY',
#   'T',
#   'WF2TCN;',
#   '37.865720759',
#   None,
#   '-122.253902513',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-3fib~vp3y.ip7k',
#   '00000000-0000-0000-A4BC-714C1529A0E2',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00007746',
#   '2019-02-12T10:39:44',
#   'SACRAMENTO ST / CEDAR ST',
#   'T',
#   'AM4TCN;',
#   '37.87668999',
#   None,
#   '-122.282646773',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-y4ca_xut3.ny8e',
#   '00000000-0000-0000-5A27-252309C1ABD0',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00000273',
#   '2019-01-02T21:04:34',
#   'MARTIN LUTHER KING JR WY / ALLSTON WY',
#   'T',
#   'OM3TCN;',
#   '37.868774479',
#   None,
#   '-122.27270445',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-w49t-34jx_jvis',
#   '00000000-0000-0000-037E-92CF3FE7653C',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00014983',
#   '2019-03-20T19:40:46',
#   '66TH ST / TELEGRAPH AV',
#   'T',
#   'OM2TCN;',
#   '37.852026902',
#   None,
#   '-122.26025423',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-dkxt.wfzr.r7t5',
#   '00000000-0000-0000-60BB-B6782F3BAC84',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00010533',
#   '2019-02-27T09:02:45',
#   'BELROSE AV / DERBY ST',
#   'T',
#   'AF4TCN;',
#   '37.862552468',
#   None,
#   '-122.245975',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ape2-5a83-xprz',
#   '00000000-0000-0000-D427-98422D259EF6',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00014742',
#   '2019-03-19T18:22:46',
#   '2000 BLOCK UNIVERSITY AVE',
#   '1194',
#   'BM3IWN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-j49w~wcfj~gyy4',
#   '00000000-0000-0000-F3A4-AC3209F1C8BB',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00016173',
#   '2019-03-26T17:54:58',
#   'COLLEGE AV / RUSSELL ST',
#   'T',
#   'BF3TCN;',
#   '37.858462205',
#   None,
#   '-122.2531766',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-42ep.r6qe.ybjb',
#   '00000000-0000-0000-D385-9F68485D17CF',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00015884',
#   '2019-03-25T11:05:37',
#   '7TH ST / MURRAY ST',
#   'T',
#   'TOW; WM4TCN; BM3TCN;',
#   '37.850806995',
#   None,
#   '-122.291036816',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-rkpu~xxkq-sqkr',
#   '00000000-0000-0000-C7E7-8B35D04E7F3F',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011419',
#   '2019-03-03T19:20:19',
#   'CHANNING WY / MILVIA ST',
#   'T',
#   'BM3TWS;',
#   '37.865458385',
#   None,
#   '-122.270007554',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-russ.2y3i_i4f9',
#   '00000000-0000-0000-5222-F1130A7AEA08',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013888',
#   '2019-03-15T19:05:31',
#   'SEAWALL DR / UNIVERSITY AV',
#   'T',
#   '000000; P;',
#   '37.863083882',
#   None,
#   '-122.317268246',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-fava~jtya_hp76',
#   '00000000-0000-0000-B247-7EB8B171854C',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00004529',
#   '2019-01-26T19:05:41',
#   'TELEGRAPH AV / ASHBY AV',
#   'T',
#   'AM2TWN;',
#   '37.856185946',
#   None,
#   '-122.259673901',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-fgtm~i5jn-amky',
#   '00000000-0000-0000-B15A-5A495FC25AB8',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00009198',
#   '2019-02-19T23:32:50',
#   '8TH ST / DWIGHT WY',
#   'T',
#   'OM2TWN;',
#   '37.86042078',
#   None,
#   '-122.292937093',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-rw9m-f8pp_iq3g',
#   '00000000-0000-0000-2511-43DEC50C9402',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00009794',
#   '2019-02-23T01:15:03',
#   'ALLSTON WY / ACTON ST',
#   'T',
#   '000000; OF4IWS; BM4IWS; M;',
#   '37.867084236',
#   None,
#   '-122.283890242',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-w5fs.5wir-6n3f',
#   '00000000-0000-0000-0A53-2A2CFAA1B325',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00010961',
#   '2019-03-01T10:36:53',
#   'MU 7',
#   'T',
#   'WM3TCN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-3u2y~tcx4.yr9e',
#   '00000000-0000-0000-8C3A-57EF387B4911',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00016161',
#   '2019-03-26T17:03:29',
#   'BLAKE ST / MARTIN LUTHER KING JR WY',
#   'T',
#   'WF4TCN;',
#   '37.862446184',
#   None,
#   '-122.271998889',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-35mr_jcas-7pfu',
#   '00000000-0000-0000-DBF8-9AAAE4773C39',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011057',
#   '2019-03-01T19:05:35',
#   'SAN PABLO AV / CEDAR ST',
#   'T',
#   'WM4TCN;',
#   '37.875204974',
#   None,
#   '-122.294094944',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ru79~pjr5~x8i8',
#   '00000000-0000-0000-B8B2-33AD225760EE',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00003926',
#   '2019-01-23T16:43:23',
#   'SACRAMENTO ST / OREGON ST',
#   'T',
#   'BM4TWS;',
#   '37.856020981',
#   None,
#   '-122.279605579',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-z8d8-8dj9-qt4e',
#   '00000000-0000-0000-32FF-EC01750E4E26',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00010696',
#   '2019-02-28T00:16:49',
#   'HEARST AV / MARTIN LUTHER KING JR WY',
#   'T',
#   'AF2TCN;',
#   '37.87330066',
#   None,
#   '-122.273195519',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-wxhv.5d5q~icbj',
#   '00000000-0000-0000-528A-CE70D01421BC',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011463',
#   '2019-03-04T00:06:05',
#   'EASTSHORE HW / GILMAN ST',
#   '1196',
#   'BM4IAS; P;',
#   '37.878302333',
#   None,
#   '-122.306565528',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-8q8i~yenv_m7uh',
#   '00000000-0000-0000-0445-13480B67AD9D',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011939',
#   '2019-03-06T14:03:38',
#   '1900 BLOCK SHATTUCK AVE',
#   '1194',
#   'BM4TWN;',
#   '37.872389512',
#   None,
#   '-122.268727725',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-bmu5.dj74.suac',
#   '00000000-0000-0000-8268-9FD347FEEB96',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00007166',
#   '2019-02-08T20:15:10',
#   'SACRAMENTO ST / HEARST AV',
#   'T',
#   'HM2TWN;',
#   '37.872149776',
#   None,
#   '-122.282132242',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-7vn5_d6g6_h6k2',
#   '00000000-0000-0000-2701-BA3AE890AC10',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013163',
#   '2019-03-12T14:51:32',
#   'ADDISON ST / SACRAMENTO ST',
#   'T',
#   'OM2TCN;',
#   '37.869432067',
#   None,
#   '-122.281843452',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-tn52~ixkq~bb6a',
#   '00000000-0000-0000-7D74-491BABD0CD95',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00006364',
#   '2019-02-04T23:23:46',
#   'ADELINE ST/ASHBY AVE',
#   'T',
#   'BF2TWN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-nxpn.uvyy_27bp',
#   '00000000-0000-0000-BD52-820F079708E4',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011350',
#   '2019-03-03T11:32:37',
#   'DERBY ST / WARRING ST',
#   'T',
#   'OM3TCN;',
#   '37.862310839',
#   None,
#   '-122.250095685',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-b2ma_xk7c.v9v4',
#   '00000000-0000-0000-D0E5-670B1EDB0C98',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013023',
#   '2019-03-11T21:39:17',
#   'MILVIA ST / CENTER ST',
#   'T',
#   'AM4TCN;',
#   '37.869981083',
#   None,
#   '-122.270548602',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-gqje-x6eu.7b6p',
#   '00000000-0000-0000-EC0E-BB40D4B50233',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011423',
#   '2019-03-03T19:40:11',
#   '2200 BLOCK SHATTUCK AVE',
#   '1194',
#   'AR;',
#   '37.868947853',
#   None,
#   '-122.267508084',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-wmgw-dga3~x9zk',
#   '00000000-0000-0000-40D8-F647089DD8A2',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00008396',
#   '2019-02-15T17:48:04',
#   '2800 BLOCK PARK ST',
#   'T',
#   'BM3TCN;',
#   '37.855501546',
#   None,
#   '-122.283088374',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-jtir~pxqk-vynk',
#   '00000000-0000-0000-EE60-C7CC72CA313F',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00012612',
#   '2019-03-09T19:49:59',
#   'SAN PABLO AV / DWIGHT WY',
#   'T',
#   'AF2TCN;',
#   '37.861094395',
#   None,
#   '-122.289545945',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-nr6h-vru7.9rcu',
#   '00000000-0000-0000-BFD1-0E1DBA047FA0',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00006512',
#   '2019-02-05T16:31:31',
#   'CAMELIA ST / SAN PABLO AV',
#   'T',
#   'HM3TCN;',
#   '37.8787405',
#   None,
#   '-122.295242624',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-5ypi~nc8m-yvih',
#   '00000000-0000-0000-0203-35169BB1EA83',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00016777',
#   '2019-03-29T17:29:02',
#   'GRAYSON ST / 7TH ST',
#   'T',
#   'P;',
#   '37.855303685',
#   None,
#   '-122.292472199',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-39ff_kwhh~uhvb',
#   '00000000-0000-0000-EBD4-D51D08D83311',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00009978',
#   '2019-02-23T23:08:16',
#   'STANFORD AV / MARKET ST',
#   'T',
#   'BF4TWN;',
#   '37.844357271',
#   None,
#   '-122.275146769',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ydtp~2db4.xxt6',
#   '00000000-0000-0000-A0BE-B59CFEA9EFF2',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00009498',
#   '2019-02-21T16:56:39',
#   'SHATTUCK AV / DURANT AV',
#   'T',
#   'BF3TWN;',
#   '37.866686775',
#   None,
#   '-122.267677303',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-mtf6_f3e4.kqxv',
#   '00000000-0000-0000-EFBB-F8DEAA1A79F0',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00001668',
#   '2019-01-10T21:59:17',
#   'SHATTUCK AV / DWIGHT WY',
#   'T',
#   'WF4TWN;',
#   '37.863971483',
#   None,
#   '-122.267363145',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-wycj~h6s7_he74',
#   '00000000-0000-0000-6FCC-E67D8D319B66',
#   0,
#   1556687429,
#   None,
# ...
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00004211',
#   '2019-01-25T03:43:15',
#   'HEARST AV / 2ND ST',
#   '1196',
#   'M;',
#   '37.868413952',
#   None,
#   '-122.302541091',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ppif~qxjg_ahn7',
#   '00000000-0000-0000-ECFE-2F6789549AF3',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00006362',
#   '2019-02-04T23:01:34',
#   '7-11 (COLLEGE)',
#   '1196',
#   'WF4TWN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-42sv_7j8a-phcz',
#   '00000000-0000-0000-7454-A90FDFFB3443',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013982',
#   '2019-03-16T01:23:02',
#   '2500 BLOCK DURANT AVE',
#   '1196',
#   'BM2IAN;',
#   '37.868211799',
#   None,
#   '-122.258033807',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-eapx-ejry~h9sa',
#   '00000000-0000-0000-5DC6-9786C2B556C0',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00017150',
#   '2019-03-31T14:00:38',
#   'SHATTUCK AV / VIRGINIA ST',
#   'T',
#   'OF2TWN;',
#   '37.876604299',
#   None,
#   '-122.268896084',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-zf2i.eae7.zxmg',
#   '00000000-0000-0000-8EFA-92AB38D2FAA4',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00000119',
#   '2019-01-01T21:46:01',
#   'GILMAN ST / 5TH ST',
#   '1194B',
#   'WM2TWN;',
#   '37.8791283',
#   None,
#   '-122.302465336',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-kdz5-qipg_bduy',
#   '00000000-0000-0000-F83C-AE18252229CC',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00006402',
#   '2019-02-05T08:19:22',
#   'JOSEPHINE ST / BERRYMAN ST',
#   'T',
#   'WF4TCN;',
#   '37.883096329',
#   None,
#   '-122.275436314',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-3eru_6v78.fiqy',
#   '00000000-0000-0000-D73B-667FC3BCAAD5',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00005304',
#   '2019-01-30T18:21:58',
#   'ASHBY AV / SAN PABLO AV',
#   'T',
#   'BF3TWN;',
#   '37.852140633',
#   None,
#   '-122.286683354',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-gm5g~8xku.vwy6',
#   '00000000-0000-0000-68F6-882E31F28BBF',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013914',
#   '2019-03-15T20:37:29',
#   'DURANT AV / ELLSWORTH ST',
#   'T',
#   'OF2TWN;',
#   '37.867219041',
#   None,
#   '-122.263540807',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-az56.fiqp.vif2',
#   '00000000-0000-0000-B382-5E55795DD320',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00006727',
#   '2019-02-06T17:20:55',
#   'CHANNING WY / MILVIA ST',
#   '1194B',
#   'WM4TWN;',
#   '37.865458385',
#   None,
#   '-122.270007554',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-wqrb~5yti.ypn4',
#   '00000000-0000-0000-7370-AD0057F9365D',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00010854',
#   '2019-02-28T17:56:18',
#   'CALIFORNIA ST / ADDISON ST',
#   'T',
#   'BM3TCN;',
#   '37.869707008',
#   None,
#   '-122.279641127',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-6ack~k43x_rq7k',
#   '00000000-0000-0000-9E72-9E39EB85E1DF',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013188',
#   '2019-03-12T16:37:15',
#   'CEDAR ST / 6TH ST',
#   'T',
#   'AM4TCN;',
#   '37.874090674',
#   None,
#   '-122.299629655',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-9czy.t3tp_e5uh',
#   '00000000-0000-0000-2448-E0BDD5E24235',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00001684',
#   '2019-01-11T00:13:40',
#   'ROSE ST / SHATTUCK AV',
#   'T',
#   'OM2TCN;',
#   '37.882023016',
#   None,
#   '-122.269536491',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-wcng.u63w.35sf',
#   '00000000-0000-0000-053F-D9EA38C392E7',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013610',
#   '2019-03-14T14:25:46',
#   '7TH ST / FOLGER AV',
#   'T',
#   'HM4TCN;',
#   '37.850058907',
#   None,
#   '-122.290783198',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-3idv_n8d8-88tj',
#   '00000000-0000-0000-2E72-5384AAB04DF2',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00003547',
#   '2019-01-21T17:23:47',
#   'DWIGHT WY / 8TH ST',
#   'T',
#   'WM4TCN;',
#   '37.86042078',
#   None,
#   '-122.292937093',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-pe7r~ze4p_wes2',
#   '00000000-0000-0000-782F-7728F8E4C515',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00012571',
#   '2019-03-09T17:18:53',
#   '1900 BLOCK SHATTUCK AVE',
#   '1194',
#   'P;',
#   '37.872389512',
#   None,
#   '-122.268727725',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-8s64.58kp_uvsh',
#   '00000000-0000-0000-B5C2-8AE4185909C0',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013864',
#   '2019-03-15T17:10:03',
#   'PARK ST / OREGON ST',
#   '1196',
#   'BF3TWN;',
#   '37.855574399',
#   None,
#   '-122.283033218',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-xvjv~3skz_6g7r',
#   '00000000-0000-0000-6A9D-1C762D226CB6',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013352',
#   '2019-03-13T12:48:27',
#   'OREGON ST / WALLACE ST',
#   '1194B',
#   'BM4TWN;',
#   '37.855044003',
#   None,
#   '-122.286592184',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-9u5m-kts5_dxmg',
#   '00000000-0000-0000-2E40-AAFC8857320A',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00006715',
#   '2019-02-06T16:53:40',
#   '2400 BLOCK 6TH ST',
#   'T',
#   'BM3TWN;',
#   '37.861700802',
#   None,
#   '-122.295708456',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-aszk~w5k2.9twm',
#   '00000000-0000-0000-9975-35055E54A688',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00000430',
#   '2019-01-03T21:53:35',
#   'HEINZ AV / SAN PABLO AV',
#   'T',
#   'WM3TWN;',
#   '37.854397327',
#   None,
#   '-122.287395909',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-8cu2_gih7-rrq6',
#   '00000000-0000-0000-6317-973D400A6974',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00012792',
#   '2019-03-10T20:27:07',
#   'SHATTUCK AV / ADDISON ST',
#   'T',
#   'AF4TCN;',
#   '37.87117011',
#   None,
#   '-122.268279654',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-f2uv.n22s_xhw6',
#   '00000000-0000-0000-E3D7-E532418569BF',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013192',
#   '2019-03-12T16:52:03',
#   '4TH ST / CEDAR ST',
#   'T',
#   'BM4TCN;',
#   '37.873651492',
#   None,
#   '-122.301815939',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-299y~fm59-xahi',
#   '00000000-0000-0000-7D21-601EB83E5D8D',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00010529',
#   '2019-02-27T08:49:05',
#   'DERBY ST / WARRING ST',
#   'T',
#   'WF4TCN;',
#   '37.862310839',
#   None,
#   '-122.250095685',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-iejf_9q6q~337s',
#   '00000000-0000-0000-4239-41DCD3AFC413',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013034',
#   '2019-03-11T22:40:05',
#   'BANCROFT WY / CALIFORNIA ST',
#   '1196',
#   'BM2TCN;',
#   '37.866103138',
#   None,
#   '-122.279282683',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ejfm-crgi~i8m6',
#   '00000000-0000-0000-B64E-DC8A1E8CDFAA',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00001502',
#   '2019-01-09T23:50:25',
#   '1500 BLOCK WALNUT ST',
#   '1194',
#   'WM4RWN;',
#   '37.88004701',
#   None,
#   '-122.268537738',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-i68f_zzw3.e5xt',
#   '00000000-0000-0000-BD44-47BD7B9EF46B',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00014591',
#   '2019-03-19T00:41:51',
#   '80 BLOCK BOLIVAR DR',
#   '1196',
#   'BM4IWN;',
#   '37.861966398',
#   None,
#   '-122.301146607',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-f6n4~bkz2_tczb',
#   '00000000-0000-0000-BC7A-4AFA59940BC5',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00006349',
#   '2019-02-04T21:38:18',
#   'ALCATRAZ/ADELINE ST',
#   'T',
#   'WM3TWS;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-j8xs~hpy7-fu94',
#   '00000000-0000-0000-6C63-1598C938B0ED',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00015638',
#   '2019-03-24T00:55:28',
#   'COLLEGE AV / ASHBY AV',
#   'T',
#   'BF2TWN;',
#   '37.857044797',
#   None,
#   '-122.253042638',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-vpdb.reah-qq2d',
#   '00000000-0000-0000-847F-3235416D00B5',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013238',
#   '2019-03-12T21:25:27',
#   'MARTIN LUTHER KING JR WY / ADDISON ST',
#   'T',
#   'OM2TCN;',
#   '37.870582456',
#   None,
#   '-122.272893186',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ur9g_zddx_szh8',
#   '00000000-0000-0000-F5D6-DCD1944686B5',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00003326',
#   '2019-01-20T09:23:17',
#   '2100 BLOCK KITTREDGE ST',
#   '1194',
#   'P;',
#   '37.868305798',
#   None,
#   '-122.266512095',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-uq86~t5c2~nx59',
#   '00000000-0000-0000-376A-0868EBF5F039',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00015743',
#   '2019-03-24T15:34:32',
#   'FRONTAGE RD / UNIVERSITY AV',
#   'T',
#   'OF4TCN;',
#   '37.86644442',
#   None,
#   '-122.305556169',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-7d7j~tt8w-8pzk',
#   '00000000-0000-0000-41C6-7412BCD07A3B',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00015936',
#   '2019-03-25T16:17:50',
#   '7TH ST / POTTER ST',
#   'T',
#   'WF3TAS;',
#   '37.851514868',
#   None,
#   '-122.291270406',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-6rih~3vkf-mwys',
#   '00000000-0000-0000-3630-B3061C6601AB',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00010585',
#   '2019-02-27T13:50:19',
#   'ADDISON ST / MARTIN LUTHER KING JR WY',
#   'T',
#   'WM2TWS;',
#   '37.870582456',
#   None,
#   '-122.272893186',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-5wqp_i6eu~ui6x',
#   '00000000-0000-0000-AA31-3998A3AFFCA8',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00002372',
#   '2019-01-15T08:58:43',
#   'ASHBY AV / TELEGRAPH AV',
#   'T',
#   'OF4TCN;',
#   '37.856185946',
#   None,
#   '-122.259673901',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-jvai~crpm_b4ww',
#   '00000000-0000-0000-C4C8-B11BA811C69F',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00017202',
#   '2019-03-31T19:41:46',
#   'ADDISON ST/BERKELEY SQ',
#   '1194',
#   'M;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-ct2u~n648~a9ar',
#   '00000000-0000-0000-6418-DFE4D00E24E4',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00010586',
#   '2019-02-27T13:51:55',
#   'SHATTUCK AV / KITTREDGE ST',
#   '1194',
#   'WM3RWN;',
#   '37.868489253',
#   None,
#   '-122.267867519',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-a96s-vcmh~ag4u',
#   '00000000-0000-0000-5C3F-6FDBE0067667',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00014024',
#   '2019-03-16T09:50:22',
#   'CEDAR ST / 2ND ST',
#   '1196',
#   '000000;',
#   '37.873189126',
#   None,
#   '-122.304077856',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-yf49_6sev-wwrz',
#   '00000000-0000-0000-D5AA-BEADC4EF380E',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00010933',
#   '2019-03-01T07:54:28',
#   '7TH ST / ANTHONY ST',
#   'T',
#   'HF2TCN;',
#   '37.85222631',
#   None,
#   '-122.291495437',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-9sgd.775e.vevb',
#   '00000000-0000-0000-5DB9-AE05F239A304',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00004355',
#   '2019-01-25T20:13:19',
#   'EDWARDS ST / CHANNING WY',
#   'T',
#   'BF2TCN;',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-e35x.x4ce~adpf',
#   '00000000-0000-0000-63BB-005B4D1683AD',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00007226',
#   '2019-02-09T07:16:16',
#   'SEAWALL DR / UNIVERSITY AV',
#   '1196',
#   'P;',
#   '37.863083882',
#   None,
#   '-122.317268246',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-y8fb-sggv-mciu',
#   '00000000-0000-0000-F337-4E56C9EB9573',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00008833',
#   '2019-02-18T00:00:34',
#   'SHATTUCK AV / VINE ST',
#   'T',
#   'AM3TWN;',
#   '37.880222206',
#   None,
#   '-122.269327183',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-cji3.a943.a6r2',
#   '00000000-0000-0000-700C-C66125951313',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011083',
#   '2019-03-01T20:34:35',
#   'SACRAMENTO ST / CHANNING WY',
#   'T',
#   'BM2TWS;',
#   '37.864002517',
#   None,
#   '-122.281286878',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-5m2h-4d24~87qi',
#   '00000000-0000-0000-2F42-2D33A1B745E8',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00016868',
#   '2019-03-30T00:08:00',
#   'ADDISON ST / 4TH ST',
#   '1194B',
#   'BM3KWS;',
#   '37.866267212',
#   None,
#   '-122.299443324',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-y53n.72f5-5hw2',
#   '00000000-0000-0000-A58D-54D7B88552C8',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00013901',
#   '2019-03-15T19:53:29',
#   'EASTSHORE HW / HARRISON ST',
#   '1194B',
#   'WM3TWS;',
#   '37.880086271',
#   None,
#   '-122.307222378',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-9nvw-9web_nuan',
#   '00000000-0000-0000-ED99-B1B89E3894D6',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00005476',
#   '2019-01-31T14:19:36',
#   'SACRAMENTO ST / ALLSTON WY',
#   'T',
#   'AF2TCN;',
#   '37.867393614',
#   None,
#   '-122.281638571',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-gx7w_86s9-zrai',
#   '00000000-0000-0000-FB34-9420B175C931',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00001158',
#   '2019-01-08T08:22:27',
#   'SAN PABLO AV / CAMELIA ST',
#   'T',
#   'HM4TWN;',
#   '37.8787405',
#   None,
#   '-122.295242624',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-b4gt.yhyr_6tkj',
#   '00000000-0000-0000-DC1D-5564F9181085',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00016444',
#   '2019-03-28T03:31:19',
#   'SAN PABLO AV / GILMAN ST',
#   '1194B',
#   'BM3TWN;',
#   '37.880474187',
#   None,
#   '-122.295799216',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['row-3ukd~2f6z.q27u',
#   '00000000-0000-0000-B4CE-73F050A1B1FB',
#   0,
#   1556687429,
#   None,
#   1556687433,
#   None,
#   '{ }',
#   '2019-00011792',
#   '2019-03-05T16:19:43',
#   '7TH ST / PARDEE ST',
#   'T',
#   'WM4TCN;',
#   '37.856082636',
#   None,
#   '-122.292728331',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ...]

# %% [markdown]
# Where can we find information on these columns? The `meta` portion of the data seems to give some indication of what columns are contained in the data. If you are able to understand the hierarchy of dictionaries that is normally encoded in a JSON file (every file is different, do not assume that all JSON files have 'meta' and 'data'!), then you will be able to figure out how to traverse it quickly. If not, we can slowly explore it, this way:

# %%
stops_dict['meta'].keys()
# Out:
# dict_keys(['view'])

# %%
stops_dict['meta']['view']
# Out:
# {'id': '6e9j-pj9p',
#  'name': 'Berkeley PD - Stop Data',
#  'attribution': 'Berkeley Police Department',
#  'averageRating': 0,
#  'category': 'Public Safety',
#  'createdAt': 1444171604,
#  'description': 'This data was extracted from the Departmentâ€™s Public Safety Server and covers the data beginning January 26, 2015.  On January 26, 2015 the department began collecting data pursuant to General Order B-4 (issued December 31, 2014).  Under that order, officers were required to provide certain data after making all vehicle detentions (including bicycles) and pedestrian detentions (up to five persons).  This data set lists stops by police in the categories of traffic, suspicious vehicle, pedestrian and bicycle stops.  Incident number, date and time, location and disposition codes are also listed in this data.\r\n\r\nAddress data has been changed from a specific address, where applicable, and listed as the block where the incident occurred.  Disposition codes were entered by officers who made the stop.  These codes included the person(s) race, gender, age (range), reason for the stop, enforcement action taken, and whether or not a search was conducted.\r\n\r\nThe officers of the Berkeley Police Department are prohibited from biased based policing, which is defined as any police-initiated action that relies on the race, ethnicity, or national origin rather than the behavior of an individual or information that leads the police to a particular individual who has been identified as being engaged in criminal activity.',
#  'displayType': 'table',
#  'downloadCount': 856,
#  'hideFromCatalog': False,
#  'hideFromDataJson': False,
#  'indexUpdatedAt': 1548643722,
#  'newBackend': True,
#  'numberOfComments': 0,
#  'oid': 28816359,
#  'provenance': 'official',
#  'publicationAppendEnabled': False,
#  'publicationDate': 1526358819,
#  'publicationGroup': 4669966,
#  'publicationStage': 'published',
#  'rowsUpdatedAt': 1566861530,
#  'rowsUpdatedBy': 'cd35-9pq2',
#  'tableId': 15200734,
#  'totalTimesRated': 0,
#  'viewCount': 5912,
#  'viewLastModified': 1566861527,
#  'viewType': 'tabular',
#  'approvals': [{'reviewedAt': 1526358819,
#    'reviewedAutomatically': True,
#    'state': 'approved',
#    'submissionId': 748167,
#    'submissionObject': 'public_audience_request',
#    'submissionOutcome': 'change_audience',
#    'submittedAt': 1526358819,
#    'workflowId': 2114,
#    'submissionDetails': {'permissionType': 'READ'},
#    'submissionOutcomeApplication': {'failureCount': 0, 'status': 'success'},
#    'submitter': {'id': 'cd35-9pq2', 'displayName': 'Police'}}],
#  'columns': [{'id': -1,
#    'name': 'sid',
#    'dataTypeName': 'meta_data',
#    'fieldName': ':sid',
#    'position': 0,
#    'renderTypeName': 'meta_data',
#    'format': {},
#    'flags': ['hidden']},
#   {'id': -1,
#    'name': 'id',
#    'dataTypeName': 'meta_data',
#    'fieldName': ':id',
#    'position': 0,
#    'renderTypeName': 'meta_data',
#    'format': {},
#    'flags': ['hidden']},
#   {'id': -1,
#    'name': 'position',
#    'dataTypeName': 'meta_data',
#    'fieldName': ':position',
#    'position': 0,
#    'renderTypeName': 'meta_data',
#    'format': {},
#    'flags': ['hidden']},
#   {'id': -1,
#    'name': 'created_at',
#    'dataTypeName': 'meta_data',
#    'fieldName': ':created_at',
#    'position': 0,
#    'renderTypeName': 'meta_data',
#    'format': {},
#    'flags': ['hidden']},
#   {'id': -1,
#    'name': 'created_meta',
#    'dataTypeName': 'meta_data',
#    'fieldName': ':created_meta',
#    'position': 0,
#    'renderTypeName': 'meta_data',
#    'format': {},
#    'flags': ['hidden']},
#   {'id': -1,
#    'name': 'updated_at',
#    'dataTypeName': 'meta_data',
#    'fieldName': ':updated_at',
#    'position': 0,
#    'renderTypeName': 'meta_data',
#    'format': {},
#    'flags': ['hidden']},
#   {'id': -1,
#    'name': 'updated_meta',
#    'dataTypeName': 'meta_data',
#    'fieldName': ':updated_meta',
#    'position': 0,
#    'renderTypeName': 'meta_data',
#    'format': {},
#    'flags': ['hidden']},
#   {'id': -1,
#    'name': 'meta',
#    'dataTypeName': 'meta_data',
#    'fieldName': ':meta',
#    'position': 0,
#    'renderTypeName': 'meta_data',
#    'format': {},
#    'flags': ['hidden']},
#   {'id': 359528059,
#    'name': 'Incident Number',
#    'dataTypeName': 'text',
#    'description': 'Number of incident created by Computer Aided Dispatch (CAD) program',
#    'fieldName': 'incident_number',
#    'position': 1,
#    'renderTypeName': 'text',
#    'tableColumnId': 31875525,
#    'width': 189,
#    'cachedContents': {'largest': '2019-00041981',
#     'non_null': 48211,
#     'null': '49',
#     'top': [{'item': '2018-00061828', 'count': '2'},
#      {'item': '2019-00004159', 'count': '2'},
#      {'item': '2018-00001818', 'count': '2'},
#      {'item': '2018-00011435', 'count': '2'},
#      {'item': '2018-00061838', 'count': '2'},
#      {'item': '2019-00000616', 'count': '2'},
#      {'item': '2019-00018982', 'count': '2'},
#      {'item': '2019-00018978', 'count': '2'},
#      {'item': '2015-00004870', 'count': '1'},
#      {'item': '2015-00004904', 'count': '1'},
#      {'item': '2015-00004865', 'count': '1'},
#      {'item': '2015-00004905', 'count': '1'},
#      {'item': '2015-00004909', 'count': '1'},
#      {'item': '2015-00004911', 'count': '1'},
#      {'item': '2015-00004831', 'count': '1'},
#      {'item': '2015-00004902', 'count': '1'},
#      {'item': '2015-00004922', 'count': '1'},
#      {'item': '2015-00004887', 'count': '1'},
#      {'item': '2015-00004849', 'count': '1'},
#      {'item': '2015-00004925', 'count': '1'}],
#     'smallest': '2015-00004825',
#     'not_null': '55034',
#     'cardinality': '55026'},
#    'format': {'align': 'left'}},
#   {'id': 359528060,
#    'name': 'Call Date/Time',
#    'dataTypeName': 'calendar_date',
#    'description': 'Date and time of the incident/stop',
#    'fieldName': 'call_date_time',
#    'position': 2,
#    'renderTypeName': 'calendar_date',
#    'tableColumnId': 31875526,
#    'width': 268,
#    'cachedContents': {'largest': '2019-07-31T23:49:57.000',
#     'non_null': 48254,
#     'null': '0',
#     'top': [{'item': '2019-04-09T17:42:33.000', 'count': '4'},
#      {'item': '2018-11-03T19:45:07.000', 'count': '4'},
#      {'item': '2016-05-27T21:28:00.000', 'count': '3'},
#      {'item': '2016-03-18T21:29:00.000', 'count': '3'},
#      {'item': '2015-03-07T20:53:00.000', 'count': '2'},
#      {'item': '2016-08-11T23:22:00.000', 'count': '2'},
#      {'item': '2016-08-24T23:00:00.000', 'count': '2'},
#      {'item': '2019-07-05T21:44:57.000', 'count': '2'},
#      {'item': '2016-06-01T00:14:00.000', 'count': '2'},
#      {'item': '2016-06-04T20:25:00.000', 'count': '2'},
#      {'item': '2015-10-24T14:52:00.000', 'count': '2'},
#      {'item': '2015-03-06T20:20:00.000', 'count': '2'},
#      {'item': '2016-01-03T16:20:00.000', 'count': '2'},
#      {'item': '2016-07-24T21:35:00.000', 'count': '2'},
#      {'item': '2016-04-03T21:36:00.000', 'count': '2'},
#      {'item': '2016-07-15T23:54:00.000', 'count': '2'},
#      {'item': '2015-09-06T19:15:00.000', 'count': '2'},
#      {'item': '2016-07-01T22:26:00.000', 'count': '2'},
#      {'item': '2016-12-02T15:06:00.000', 'count': '2'},
#      {'item': '2015-02-04T12:11:00.000', 'count': '2'}],
#     'smallest': '2015-01-26T00:10:00.000',
#     'not_null': '55083',
#     'cardinality': '54699'},
#    'format': {'view': 'date_time', 'align': 'left'}},
#   {'id': 359528061,
#    'name': 'Location',
#    'dataTypeName': 'text',
#    'description': 'General location of the incident/stop',
#    'fieldName': 'location',
#    'position': 3,
#    'renderTypeName': 'text',
#    'tableColumnId': 31875527,
#    'width': 196,
#    'cachedContents': {'largest': ' YALE AVE/RUGBY AVE',
#     'non_null': 48084,
#     'null': '364',
#     'top': [{'item': '80 BLOCK BOLIVAR DR', 'count': '332'},
#      {'item': '2200 BLOCK SHATTUCK AVE', 'count': '312'},
#      {'item': '37.8693028530001~-122.272234021', 'count': '213'},
#      {'item': 'UNIVERSITY AVE / SAN PABLO AVE', 'count': '202'},
#      {'item': 'UNIVERSITY AVE / SIXTH ST', 'count': '182'},
#      {'item': ' SEVENTH ST /  POTTER ST', 'count': '172'},
#      {'item': '1900 BLOCK SHATTUCK AVE', 'count': '172'},
#      {'item': ' ASHBY AVE /  SEVENTH ST', 'count': '161'},
#      {'item': '2100 BLOCK SHATTUCK AVE', 'count': '146'},
#      {'item': '100 BLOCK SEAWALL DR', 'count': '142'},
#      {'item': 'SAN PABLO AVE / UNIVERSITY AVE', 'count': '142'},
#      {'item': ' UNIVERSITY AVE /  SAN PABLO AVE', 'count': '141'},
#      {'item': 'ASHBY AVE / SAN PABLO AVE', 'count': '136'},
#      {'item': ' SEVENTH ST /  ASHBY AVE', 'count': '133'},
#      {'item': 'ASHBY AVE / SEVENTH ST', 'count': '131'},
#      {'item': 'UNIVERSITY AVE / ACTON ST', 'count': '129'},
#      {'item': ' UNIVERSITY AVE /  SIXTH ST', 'count': '128'},
#      {'item': ' POTTER ST /  SEVENTH ST', 'count': '126'},
#      {'item': 'SHATTUCK AVE / KITTREDGE ST', 'count': '126'},
#      {'item': 'SIXTH ST / UNIVERSITY AVE', 'count': '124'}],
#     'smallest': '0 BLOCK BAN',
#     'not_null': '54719',
#     'cardinality': '10802'},
#    'format': {'align': 'left'}},
#   {'id': 359528062,
#    'name': 'Incident Type',
#    'dataTypeName': 'text',
#    'description': 'This is the occurred incident type created in the CAD program.  A code signifies a traffic stop (T), suspicious vehicle stop (1196), pedestrian stop (1194) and bicycle stop (1194B).',
#    'fieldName': 'incident_type',
#    'position': 4,
#    'renderTypeName': 'text',
#    'tableColumnId': 31875528,
#    'width': 256,
#    'cachedContents': {'largest': 'T',
#     'non_null': 48254,
#     'null': '0',
#     'top': [{'item': 'T', 'count': '40751'},
#      {'item': '1194', 'count': '7928'},
#      {'item': '1196', 'count': '3914'},
#      {'item': '1194B', 'count': '2490'}],
#     'smallest': '1194',
#     'not_null': '55083',
#     'cardinality': '4'},
#    'format': {'align': 'left'}},
#   {'id': 359528063,
#    'name': 'Dispositions',
#    'dataTypeName': 'text',
#    'description': 'Ordered in the following sequence:\n1st Character = Race, as follows:\nA (Asian) B (Black) H (Hispanic) O (Other) W (White)\n2nd Character = Gender, as follows:\nF (Female) M (Male)\n3rd Character = Age Range, as follows:\n1 (Less than 18) 2 (18-29) 3 (30-39), 4 (Greater than 40)\n4th Character = Reason, as follows:\nI (Investigation) T (Traffic) R (Reasonable Suspicion)\nK (Probation/Parole) W (Wanted)\n5th Character = Enforcement, as follows:\nA (Arrest) C (Citation) O (Other) W (Warning)\n6th Character = Car Search, as follows:\nS (Search) N (No Search)\n\nAdditional dispositions may also appear.  They are:\nP - Primary case report\nM - MDT narrative only\nAR - Arrest report only (no case report submitted)\nIN - Incident report\nFC - Field Card\nCO - Collision investigation report\nMH - Emergency Psychiatric Evaluation\nTOW - Impounded vehicle\n0 or 00000 â€“ Officer made a stop of more than five persons',
#    'fieldName': 'dispositions',
#    'position': 5,
#    'renderTypeName': 'text',
#    'tableColumnId': 31875529,
#    'width': 244,
#    'cachedContents': {'largest': 'zz do not use Assist; ',
#     'non_null': 48161,
#     'null': '113',
#     'top': [{'item': 'M', 'count': '1683'},
#      {'item': 'M; ', 'count': '933'},
#      {'item': 'WM4TCN', 'count': '875'},
#      {'item': 'M;', 'count': '782'},
#      {'item': 'WM4TCN; ', 'count': '704'},
#      {'item': 'BM4TWN', 'count': '681'},
#      {'item': 'BM2TWN', 'count': '674'},
#      {'item': 'BM4TWN; ', 'count': '630'},
#      {'item': 'WM4TWN; ', 'count': '617'},
#      {'item': 'WM4TWN', 'count': '547'},
#      {'item': 'WF4TCN', 'count': '537'},
#      {'item': 'BM2TWN; ', 'count': '528'},
#      {'item': 'WF4TCN; ', 'count': '517'},
#      {'item': 'BM4TWN;', 'count': '499'},
#      {'item': 'P', 'count': '493'},
#      {'item': 'WM2TWN', 'count': '487'},
#      {'item': 'P; ', 'count': '454'},
#      {'item': 'WM4TCN;', 'count': '452'},
#      {'item': 'WM4TWN;', 'count': '440'},
#      {'item': 'BM2TWN;', 'count': '434'}],
#     'smallest': '0',
#     'not_null': '54970',
#     'cardinality': '4534'},
#    'format': {'align': 'left'}},
#   {'id': 359528065,
#    'name': 'Location - Latitude',
#    'dataTypeName': 'number',
#    'description': 'General latitude of the call.  This data is only uploaded after January 2017',
#    'fieldName': 'latitude',
#    'position': 7,
#    'rdfProperties': 'http://www.w3.org/2003/01/geo/wgs84_pos#lat',
#    'renderTypeName': 'number',
#    'tableColumnId': 48452939,
#    'width': 100,
#    'cachedContents': {'largest': '37.900832366',
#     'non_null': 22054,
#     'average': '37.86416470568613',
#     'null': '26720',
#     'top': [{'item': '37.8515148720001', 'count': '298'},
#      {'item': '37.8510085500001', 'count': '294'},
#      {'item': '37.871555254', 'count': '268'},
#      {'item': '37.8679950200001', 'count': '246'},
#      {'item': '37.8690965960001', 'count': '241'},
#      {'item': '37.852154468', 'count': '178'},
#      {'item': '37.872151456', 'count': '166'},
#      {'item': '37.8532107497425', 'count': '143'},
#      {'item': '37.869096584', 'count': '142'},
#      {'item': '37.8664441110001', 'count': '139'},
#      {'item': '37.851008546', 'count': '136'},
#      {'item': '37.8619663980001', 'count': '131'},
#      {'item': '37.851632511', 'count': '125'},
#      {'item': '37.8684892540001', 'count': '124'},
#      {'item': '37.850058909', 'count': '116'},
#      {'item': '37.8704105630001', 'count': '115'},
#      {'item': '37.867993895', 'count': '115'},
#      {'item': '37.8543163850001', 'count': '111'},
#      {'item': '37.852140633', 'count': '109'},
#      {'item': '37.8532810940001', 'count': '109'}],
#     'smallest': '37.616572406',
#     'not_null': '28363',
#     'sum': '835056.2884192018039',
#     'cardinality': '3476'},
#    'format': {'precisionStyle': 'standard',
#     'rdf': 'http://www.w3.org/2003/01/geo/wgs84_pos#lat',
#     'noCommas': 'false',
#     'align': 'right'}},
#   {'id': 404677359,
#    'name': 'Location 1 (address)',
#    'dataTypeName': 'text',
#    'fieldName': 'location_1_address',
#    'position': 7,
#    'renderTypeName': 'text',
#    'tableColumnId': 79600279,
#    'cachedContents': {'largest': 'WOOLSEY ST / REGENT ST',
#     'non_null': '8100',
#     'null': '46983',
#     'top': [{'item': '2200 BLOCK SHATTUCK AVE', 'count': '125'},
#      {'item': '2400 BLOCK TELEGRAPH AVE', 'count': '78'},
#      {'item': 'UNIVERSITY AVE / SAN PABLO AVE', 'count': '77'},
#      {'item': '37.8693028530001~-122.272234021', 'count': '77'},
#      {'item': '2100 BLOCK SHATTUCK AVE', 'count': '74'},
#      {'item': 'UNIVERSITY AVE / SIXTH ST', 'count': '67'},
#      {'item': 'SHATTUCK AVE / KITTREDGE ST', 'count': '66'},
#      {'item': 'UNIVERSITY AVE / ACTON ST', 'count': '62'},
#      {'item': '2500 BLOCK TELEGRAPH AVE', 'count': '56'},
#      {'item': 'SAN PABLO AVE / UNIVERSITY AVE', 'count': '54'},
#      {'item': 'ASHBY AVE / SAN PABLO AVE', 'count': '46'},
#      {'item': 'UNIVERSITY AVE / SACRAMENTO ST', 'count': '45'},
#      {'item': 'UNIVERSITY AVE / BONAR ST', 'count': '42'},
#      {'item': 'CEDAR ST / ACTON ST', 'count': '41'},
#      {'item': 'SIXTH ST / UNIVERSITY AVE', 'count': '41'},
#      {'item': 'UNIVERSITY AVE / NINTH ST', 'count': '40'},
#      {'item': 'ASHBY AVE / SEVENTH ST', 'count': '40'},
#      {'item': 'CENTER ST / SHATTUCK AVE', 'count': '39'},
#      {'item': '37.8609962420001~-122.256143699', 'count': '39'},
#      {'item': 'UNIVERSITY AVE / W FRONTAGE RD', 'count': '38'}],
#     'smallest': '1000 BLOCK ALLSTON WAY',
#     'cardinality': '2303'},
#    'format': {}},
#   {'id': 359528066,
#    'name': 'Location - Longitude',
#    'dataTypeName': 'number',
#    'description': 'General longitude of the call.  This data is only uploaded after January 2017.',
#    'fieldName': 'longitude',
#    'position': 8,
#    'rdfProperties': 'http://www.w3.org/2003/01/geo/wgs84_pos#long',
#    'renderTypeName': 'number',
#    'tableColumnId': 48452945,
#    'width': 100,
#    'cachedContents': {'largest': '-121.761030941',
#     'non_null': 22054,
#     'average': '-122.2801422863971',
#     'null': '26720',
#     'top': [{'item': '-122.291270407', 'count': '298'},
#      {'item': '-122.291104034', 'count': '294'},
#      {'item': '-122.297664755', 'count': '246'},
#      {'item': '-122.292119433', 'count': '241'},
#      {'item': '-122.301146607', 'count': '201'},
#      {'item': '-122.286676764', 'count': '178'},
#      {'item': '-122.284248934', 'count': '168'},
#      {'item': '-122.268413931', 'count': '166'},
#      {'item': '-122.273001342', 'count': '157'},
#      {'item': '-122.29714472956', 'count': '143'},
#      {'item': '-122.292119436', 'count': '142'},
#      {'item': '-122.305556569', 'count': '139'},
#      {'item': '-122.268727725', 'count': '139'},
#      {'item': '-122.291104031', 'count': '136'},
#      {'item': '-122.289400879', 'count': '125'},
#      {'item': '-122.26786752', 'count': '124'},
#      {'item': '-122.27270445', 'count': '122'},
#      {'item': '-122.290783207', 'count': '116'},
#      {'item': '-122.297664386', 'count': '115'},
#      {'item': '-122.281937984', 'count': '115'}],
#     'smallest': '-122.337056283',
#     'not_null': '28363',
#     'sum': '-2696766.257984202135',
#     'cardinality': '3417'},
#    'format': {'precisionStyle': 'standard',
#     'rdf': 'http://www.w3.org/2003/01/geo/wgs84_pos#long',
#     'noCommas': 'false',
#     'align': 'right'}},
#   {'id': 404677357,
#    'name': 'Location 1 (city)',
#    'dataTypeName': 'text',
#    'fieldName': 'location_1_city',
#    'position': 8,
#    'renderTypeName': 'text',
#    'tableColumnId': 79600277,
#    'cachedContents': {'largest': 'Oakland',
#     'non_null': '7291',
#     'null': '47792',
#     'top': [{'item': 'Berkeley', 'count': '6897'},
#      {'item': 'Oakland', 'count': '334'},
#      {'item': 'Emeryville', 'count': '47'},
#      {'item': 'Albany', 'count': '12'},
#      {'item': 'C4', 'count': '1'}],
#     'smallest': 'Albany',
#     'cardinality': '5'},
#    'format': {}},
#   {'id': 404677358,
#    'name': 'Location 1 (state)',
#    'dataTypeName': 'text',
#    'fieldName': 'location_1_state',
#    'position': 9,
#    'renderTypeName': 'text',
#    'tableColumnId': 79600278,
#    'cachedContents': {'largest': 'CA',
#     'non_null': '8101',
#     'null': '46982',
#     'top': [{'item': 'CA', 'count': '8101'}],
#     'smallest': 'CA',
#     'cardinality': '1'},
#    'format': {}},
#   {'id': 404677356,
#    'name': 'Location 1 (zip)',
#    'dataTypeName': 'text',
#    'fieldName': 'location_1_zip',
#    'position': 10,
#    'renderTypeName': 'text',
#    'tableColumnId': 79600276,
#    'cachedContents': {'non_null': '0', 'null': '55083', 'cardinality': '0'},
#    'format': {}},
#   {'id': 404677362,
#    'name': 'Council Districts_uniq_prepend',
#    'dataTypeName': 'number',
#    'fieldName': ':@computed_region_b3wi_w8ix',
#    'position': 13,
#    'renderTypeName': 'number',
#    'tableColumnId': 79600282,
#    'format': {}},
#   {'id': 404677363,
#    'name': 'Council Districts_from_hg3u_n7v4',
#    'dataTypeName': 'number',
#    'fieldName': ':@computed_region_fhmw_rucx',
#    'position': 14,
#    'renderTypeName': 'number',
#    'tableColumnId': 79600283,
#    'format': {}},
#   {'id': 404677364,
#    'name': 'Council Districts_from_c8zs_8y7x',
#    'dataTypeName': 'number',
#    'fieldName': ':@computed_region_u3y2_d2ws',
#    'position': 15,
#    'renderTypeName': 'number',
#    'tableColumnId': 79600284,
#    'format': {}},
#   {'id': 404677365,
#    'name': 'Zip Codes',
#    'dataTypeName': 'number',
#    'fieldName': ':@computed_region_5s6d_2f32',
#    'position': 16,
#    'renderTypeName': 'number',
#    'tableColumnId': 79600285,
#    'format': {}},
#   {'id': 404677366,
#    'name': 'Police Beats',
#    'dataTypeName': 'number',
#    'fieldName': ':@computed_region_3ini_iehf',
#    'position': 17,
#    'renderTypeName': 'number',
#    'tableColumnId': 79600286,
#    'format': {}},
#   {'id': 404677367,
#    'name': 'Census Tracts',
#    'dataTypeName': 'number',
#    'fieldName': ':@computed_region_5bih_7r3y',
#    'position': 18,
#    'renderTypeName': 'number',
#    'tableColumnId': 79600287,
#    'format': {}},
#   {'id': 404677368,
#    'name': 'Council Districts',
#    'dataTypeName': 'number',
#    'fieldName': ':@computed_region_x3q3_gi3e',
#    'position': 19,
#    'renderTypeName': 'number',
#    'tableColumnId': 79600288,
#    'format': {}}],
#  'grants': [{'inherited': False, 'type': 'viewer', 'flags': ['public']}],
#  'metadata': {'rdfSubject': '0',
#   'jsonQuery': {'order': [{'columnFieldName': 'incident_number',
#      'ascending': True}]},
#   'attachments': [{'filename': 'ODP Upload Narrative 01-14-16.pdf',
#     'assetId': '44de7d3a-0b4c-485d-80fe-c17d3d134a9e',
#     'name': 'ODP Upload Narrative 01-14-16.pdf'}],
#   'custom_fields': {'Required fields': {'One Page Narrative': 'This data was extracted from the Departmentâ€™s Public Safety Server and covers the dates from January 26, 2015 through the most present upload of data.  On January 26, 2015 the department began collecting data pursuant to General Order B-4 (issued December 31, 2014).  Under that order, officers were required to provide certain data after making all vehicle detentions (including bicycles) and pedestrian detentions (up to five persons).  This data set lists stops by police in the categories of traffic, suspicious vehicle, pedestrian and bicycle stops.  Incident number, date and time, location and disposition codes are also listed in this data.  Address data has been changed from a specific address, where applicable, and listed as the block where the incident occurred.  Disposition codes were entered by officers who made the stop.  These codes included the person(s) race, gender, age (range), reason for the stop, enforcement action taken, and whether or not a search was conducted.  The officers of the Berkeley Police Department are prohibited from biased based policing, which is defined as any police-initiated action that relies on the race, ethnicity, or national origin rather than the behavior of an individual or information that leads the police to a particular individual who has been identified as being engaged in criminal activity.'}},
#   'rowLabel': 'N/A',
#   'availableDisplayTypes': ['table', 'fatrow', 'page'],
#   'renderTypeConfig': {'visible': {'table': True}}},
#  'owner': {'id': 'cd35-9pq2',
#   'displayName': 'Police',
#   'screenName': 'Police',
#   'type': 'interactive',
#   'userSegment': 'site_member'},
#  'query': {'orderBys': [{'ascending': True,
#     'expression': {'columnId': 359528059, 'type': 'column'}}]},
#  'rights': ['read'],
#  'tableAuthor': {'id': 'cd35-9pq2',
#   'displayName': 'Police',
#   'screenName': 'Police',
#   'type': 'interactive',
#   'userSegment': 'site_member'},
#  'tags': ['police',
#   'stop data',
#   'traffic',
#   'pedestrian',
#   'vehicle',
#   'bike',
#   'race',
#   'gender',
#   'age',
#   'reason',
#   'enforcement',
#   'search'],
#  'flags': ['default', 'restorable', 'restorePossibleForType']}

# %%
stops_dict['meta']['view'].keys()
# Out:
# dict_keys(['id', 'name', 'attribution', 'averageRating', 'category', 'createdAt', 'description', 'displayType', 'downloadCount', 'hideFromCatalog', 'hideFromDataJson', 'indexUpdatedAt', 'newBackend', 'numberOfComments', 'oid', 'provenance', 'publicationAppendEnabled', 'publicationDate', 'publicationGroup', 'publicationStage', 'rowsUpdatedAt', 'rowsUpdatedBy', 'tableId', 'totalTimesRated', 'viewCount', 'viewLastModified', 'viewType', 'approvals', 'columns', 'grants', 'metadata', 'owner', 'query', 'rights', 'tableAuthor', 'tags', 'flags'])

# %%
stops_dict['meta']['view']['columns']
# Out:
# [{'id': -1,
#   'name': 'sid',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':sid',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'id',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':id',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'position',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':position',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'created_at',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':created_at',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'created_meta',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':created_meta',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'updated_at',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':updated_at',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'updated_meta',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':updated_meta',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'meta',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':meta',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': 359528059,
#   'name': 'Incident Number',
#   'dataTypeName': 'text',
#   'description': 'Number of incident created by Computer Aided Dispatch (CAD) program',
#   'fieldName': 'incident_number',
#   'position': 1,
#   'renderTypeName': 'text',
#   'tableColumnId': 31875525,
#   'width': 189,
#   'cachedContents': {'largest': '2019-00041981',
#    'non_null': 48211,
#    'null': '49',
#    'top': [{'item': '2018-00061828', 'count': '2'},
#     {'item': '2019-00004159', 'count': '2'},
#     {'item': '2018-00001818', 'count': '2'},
#     {'item': '2018-00011435', 'count': '2'},
#     {'item': '2018-00061838', 'count': '2'},
#     {'item': '2019-00000616', 'count': '2'},
#     {'item': '2019-00018982', 'count': '2'},
#     {'item': '2019-00018978', 'count': '2'},
#     {'item': '2015-00004870', 'count': '1'},
#     {'item': '2015-00004904', 'count': '1'},
#     {'item': '2015-00004865', 'count': '1'},
#     {'item': '2015-00004905', 'count': '1'},
#     {'item': '2015-00004909', 'count': '1'},
#     {'item': '2015-00004911', 'count': '1'},
#     {'item': '2015-00004831', 'count': '1'},
#     {'item': '2015-00004902', 'count': '1'},
#     {'item': '2015-00004922', 'count': '1'},
#     {'item': '2015-00004887', 'count': '1'},
#     {'item': '2015-00004849', 'count': '1'},
#     {'item': '2015-00004925', 'count': '1'}],
#    'smallest': '2015-00004825',
#    'not_null': '55034',
#    'cardinality': '55026'},
#   'format': {'align': 'left'}},
#  {'id': 359528060,
#   'name': 'Call Date/Time',
#   'dataTypeName': 'calendar_date',
#   'description': 'Date and time of the incident/stop',
#   'fieldName': 'call_date_time',
#   'position': 2,
#   'renderTypeName': 'calendar_date',
#   'tableColumnId': 31875526,
#   'width': 268,
#   'cachedContents': {'largest': '2019-07-31T23:49:57.000',
#    'non_null': 48254,
#    'null': '0',
#    'top': [{'item': '2019-04-09T17:42:33.000', 'count': '4'},
#     {'item': '2018-11-03T19:45:07.000', 'count': '4'},
#     {'item': '2016-05-27T21:28:00.000', 'count': '3'},
#     {'item': '2016-03-18T21:29:00.000', 'count': '3'},
#     {'item': '2015-03-07T20:53:00.000', 'count': '2'},
#     {'item': '2016-08-11T23:22:00.000', 'count': '2'},
#     {'item': '2016-08-24T23:00:00.000', 'count': '2'},
#     {'item': '2019-07-05T21:44:57.000', 'count': '2'},
#     {'item': '2016-06-01T00:14:00.000', 'count': '2'},
#     {'item': '2016-06-04T20:25:00.000', 'count': '2'},
#     {'item': '2015-10-24T14:52:00.000', 'count': '2'},
#     {'item': '2015-03-06T20:20:00.000', 'count': '2'},
#     {'item': '2016-01-03T16:20:00.000', 'count': '2'},
#     {'item': '2016-07-24T21:35:00.000', 'count': '2'},
#     {'item': '2016-04-03T21:36:00.000', 'count': '2'},
#     {'item': '2016-07-15T23:54:00.000', 'count': '2'},
#     {'item': '2015-09-06T19:15:00.000', 'count': '2'},
#     {'item': '2016-07-01T22:26:00.000', 'count': '2'},
#     {'item': '2016-12-02T15:06:00.000', 'count': '2'},
#     {'item': '2015-02-04T12:11:00.000', 'count': '2'}],
#    'smallest': '2015-01-26T00:10:00.000',
#    'not_null': '55083',
#    'cardinality': '54699'},
#   'format': {'view': 'date_time', 'align': 'left'}},
#  {'id': 359528061,
#   'name': 'Location',
#   'dataTypeName': 'text',
#   'description': 'General location of the incident/stop',
#   'fieldName': 'location',
#   'position': 3,
#   'renderTypeName': 'text',
#   'tableColumnId': 31875527,
#   'width': 196,
#   'cachedContents': {'largest': ' YALE AVE/RUGBY AVE',
#    'non_null': 48084,
#    'null': '364',
#    'top': [{'item': '80 BLOCK BOLIVAR DR', 'count': '332'},
#     {'item': '2200 BLOCK SHATTUCK AVE', 'count': '312'},
#     {'item': '37.8693028530001~-122.272234021', 'count': '213'},
#     {'item': 'UNIVERSITY AVE / SAN PABLO AVE', 'count': '202'},
#     {'item': 'UNIVERSITY AVE / SIXTH ST', 'count': '182'},
#     {'item': ' SEVENTH ST /  POTTER ST', 'count': '172'},
#     {'item': '1900 BLOCK SHATTUCK AVE', 'count': '172'},
#     {'item': ' ASHBY AVE /  SEVENTH ST', 'count': '161'},
#     {'item': '2100 BLOCK SHATTUCK AVE', 'count': '146'},
#     {'item': '100 BLOCK SEAWALL DR', 'count': '142'},
#     {'item': 'SAN PABLO AVE / UNIVERSITY AVE', 'count': '142'},
#     {'item': ' UNIVERSITY AVE /  SAN PABLO AVE', 'count': '141'},
#     {'item': 'ASHBY AVE / SAN PABLO AVE', 'count': '136'},
#     {'item': ' SEVENTH ST /  ASHBY AVE', 'count': '133'},
#     {'item': 'ASHBY AVE / SEVENTH ST', 'count': '131'},
#     {'item': 'UNIVERSITY AVE / ACTON ST', 'count': '129'},
#     {'item': ' UNIVERSITY AVE /  SIXTH ST', 'count': '128'},
#     {'item': ' POTTER ST /  SEVENTH ST', 'count': '126'},
#     {'item': 'SHATTUCK AVE / KITTREDGE ST', 'count': '126'},
#     {'item': 'SIXTH ST / UNIVERSITY AVE', 'count': '124'}],
#    'smallest': '0 BLOCK BAN',
#    'not_null': '54719',
#    'cardinality': '10802'},
#   'format': {'align': 'left'}},
#  {'id': 359528062,
#   'name': 'Incident Type',
#   'dataTypeName': 'text',
#   'description': 'This is the occurred incident type created in the CAD program.  A code signifies a traffic stop (T), suspicious vehicle stop (1196), pedestrian stop (1194) and bicycle stop (1194B).',
#   'fieldName': 'incident_type',
#   'position': 4,
#   'renderTypeName': 'text',
#   'tableColumnId': 31875528,
#   'width': 256,
#   'cachedContents': {'largest': 'T',
#    'non_null': 48254,
#    'null': '0',
#    'top': [{'item': 'T', 'count': '40751'},
#     {'item': '1194', 'count': '7928'},
#     {'item': '1196', 'count': '3914'},
#     {'item': '1194B', 'count': '2490'}],
#    'smallest': '1194',
#    'not_null': '55083',
#    'cardinality': '4'},
#   'format': {'align': 'left'}},
#  {'id': 359528063,
#   'name': 'Dispositions',
#   'dataTypeName': 'text',
#   'description': 'Ordered in the following sequence:\n1st Character = Race, as follows:\nA (Asian) B (Black) H (Hispanic) O (Other) W (White)\n2nd Character = Gender, as follows:\nF (Female) M (Male)\n3rd Character = Age Range, as follows:\n1 (Less than 18) 2 (18-29) 3 (30-39), 4 (Greater than 40)\n4th Character = Reason, as follows:\nI (Investigation) T (Traffic) R (Reasonable Suspicion)\nK (Probation/Parole) W (Wanted)\n5th Character = Enforcement, as follows:\nA (Arrest) C (Citation) O (Other) W (Warning)\n6th Character = Car Search, as follows:\nS (Search) N (No Search)\n\nAdditional dispositions may also appear.  They are:\nP - Primary case report\nM - MDT narrative only\nAR - Arrest report only (no case report submitted)\nIN - Incident report\nFC - Field Card\nCO - Collision investigation report\nMH - Emergency Psychiatric Evaluation\nTOW - Impounded vehicle\n0 or 00000 â€“ Officer made a stop of more than five persons',
#   'fieldName': 'dispositions',
#   'position': 5,
#   'renderTypeName': 'text',
#   'tableColumnId': 31875529,
#   'width': 244,
#   'cachedContents': {'largest': 'zz do not use Assist; ',
#    'non_null': 48161,
#    'null': '113',
#    'top': [{'item': 'M', 'count': '1683'},
#     {'item': 'M; ', 'count': '933'},
#     {'item': 'WM4TCN', 'count': '875'},
#     {'item': 'M;', 'count': '782'},
#     {'item': 'WM4TCN; ', 'count': '704'},
#     {'item': 'BM4TWN', 'count': '681'},
#     {'item': 'BM2TWN', 'count': '674'},
#     {'item': 'BM4TWN; ', 'count': '630'},
#     {'item': 'WM4TWN; ', 'count': '617'},
#     {'item': 'WM4TWN', 'count': '547'},
#     {'item': 'WF4TCN', 'count': '537'},
#     {'item': 'BM2TWN; ', 'count': '528'},
#     {'item': 'WF4TCN; ', 'count': '517'},
#     {'item': 'BM4TWN;', 'count': '499'},
#     {'item': 'P', 'count': '493'},
#     {'item': 'WM2TWN', 'count': '487'},
#     {'item': 'P; ', 'count': '454'},
#     {'item': 'WM4TCN;', 'count': '452'},
#     {'item': 'WM4TWN;', 'count': '440'},
#     {'item': 'BM2TWN;', 'count': '434'}],
#    'smallest': '0',
#    'not_null': '54970',
#    'cardinality': '4534'},
#   'format': {'align': 'left'}},
#  {'id': 359528065,
#   'name': 'Location - Latitude',
#   'dataTypeName': 'number',
#   'description': 'General latitude of the call.  This data is only uploaded after January 2017',
#   'fieldName': 'latitude',
#   'position': 7,
#   'rdfProperties': 'http://www.w3.org/2003/01/geo/wgs84_pos#lat',
#   'renderTypeName': 'number',
#   'tableColumnId': 48452939,
#   'width': 100,
#   'cachedContents': {'largest': '37.900832366',
#    'non_null': 22054,
#    'average': '37.86416470568613',
#    'null': '26720',
#    'top': [{'item': '37.8515148720001', 'count': '298'},
#     {'item': '37.8510085500001', 'count': '294'},
#     {'item': '37.871555254', 'count': '268'},
#     {'item': '37.8679950200001', 'count': '246'},
#     {'item': '37.8690965960001', 'count': '241'},
#     {'item': '37.852154468', 'count': '178'},
#     {'item': '37.872151456', 'count': '166'},
#     {'item': '37.8532107497425', 'count': '143'},
#     {'item': '37.869096584', 'count': '142'},
#     {'item': '37.8664441110001', 'count': '139'},
#     {'item': '37.851008546', 'count': '136'},
#     {'item': '37.8619663980001', 'count': '131'},
#     {'item': '37.851632511', 'count': '125'},
#     {'item': '37.8684892540001', 'count': '124'},
#     {'item': '37.850058909', 'count': '116'},
#     {'item': '37.8704105630001', 'count': '115'},
#     {'item': '37.867993895', 'count': '115'},
#     {'item': '37.8543163850001', 'count': '111'},
#     {'item': '37.852140633', 'count': '109'},
#     {'item': '37.8532810940001', 'count': '109'}],
#    'smallest': '37.616572406',
#    'not_null': '28363',
#    'sum': '835056.2884192018039',
#    'cardinality': '3476'},
#   'format': {'precisionStyle': 'standard',
#    'rdf': 'http://www.w3.org/2003/01/geo/wgs84_pos#lat',
#    'noCommas': 'false',
#    'align': 'right'}},
#  {'id': 404677359,
#   'name': 'Location 1 (address)',
#   'dataTypeName': 'text',
#   'fieldName': 'location_1_address',
#   'position': 7,
#   'renderTypeName': 'text',
#   'tableColumnId': 79600279,
#   'cachedContents': {'largest': 'WOOLSEY ST / REGENT ST',
#    'non_null': '8100',
#    'null': '46983',
#    'top': [{'item': '2200 BLOCK SHATTUCK AVE', 'count': '125'},
#     {'item': '2400 BLOCK TELEGRAPH AVE', 'count': '78'},
#     {'item': 'UNIVERSITY AVE / SAN PABLO AVE', 'count': '77'},
#     {'item': '37.8693028530001~-122.272234021', 'count': '77'},
#     {'item': '2100 BLOCK SHATTUCK AVE', 'count': '74'},
#     {'item': 'UNIVERSITY AVE / SIXTH ST', 'count': '67'},
#     {'item': 'SHATTUCK AVE / KITTREDGE ST', 'count': '66'},
#     {'item': 'UNIVERSITY AVE / ACTON ST', 'count': '62'},
#     {'item': '2500 BLOCK TELEGRAPH AVE', 'count': '56'},
#     {'item': 'SAN PABLO AVE / UNIVERSITY AVE', 'count': '54'},
#     {'item': 'ASHBY AVE / SAN PABLO AVE', 'count': '46'},
#     {'item': 'UNIVERSITY AVE / SACRAMENTO ST', 'count': '45'},
#     {'item': 'UNIVERSITY AVE / BONAR ST', 'count': '42'},
#     {'item': 'CEDAR ST / ACTON ST', 'count': '41'},
#     {'item': 'SIXTH ST / UNIVERSITY AVE', 'count': '41'},
#     {'item': 'UNIVERSITY AVE / NINTH ST', 'count': '40'},
#     {'item': 'ASHBY AVE / SEVENTH ST', 'count': '40'},
#     {'item': 'CENTER ST / SHATTUCK AVE', 'count': '39'},
#     {'item': '37.8609962420001~-122.256143699', 'count': '39'},
#     {'item': 'UNIVERSITY AVE / W FRONTAGE RD', 'count': '38'}],
#    'smallest': '1000 BLOCK ALLSTON WAY',
#    'cardinality': '2303'},
#   'format': {}},
#  {'id': 359528066,
#   'name': 'Location - Longitude',
#   'dataTypeName': 'number',
#   'description': 'General longitude of the call.  This data is only uploaded after January 2017.',
#   'fieldName': 'longitude',
#   'position': 8,
#   'rdfProperties': 'http://www.w3.org/2003/01/geo/wgs84_pos#long',
#   'renderTypeName': 'number',
#   'tableColumnId': 48452945,
#   'width': 100,
#   'cachedContents': {'largest': '-121.761030941',
#    'non_null': 22054,
#    'average': '-122.2801422863971',
#    'null': '26720',
#    'top': [{'item': '-122.291270407', 'count': '298'},
#     {'item': '-122.291104034', 'count': '294'},
#     {'item': '-122.297664755', 'count': '246'},
#     {'item': '-122.292119433', 'count': '241'},
#     {'item': '-122.301146607', 'count': '201'},
#     {'item': '-122.286676764', 'count': '178'},
#     {'item': '-122.284248934', 'count': '168'},
#     {'item': '-122.268413931', 'count': '166'},
#     {'item': '-122.273001342', 'count': '157'},
#     {'item': '-122.29714472956', 'count': '143'},
#     {'item': '-122.292119436', 'count': '142'},
#     {'item': '-122.305556569', 'count': '139'},
#     {'item': '-122.268727725', 'count': '139'},
#     {'item': '-122.291104031', 'count': '136'},
#     {'item': '-122.289400879', 'count': '125'},
#     {'item': '-122.26786752', 'count': '124'},
#     {'item': '-122.27270445', 'count': '122'},
#     {'item': '-122.290783207', 'count': '116'},
#     {'item': '-122.297664386', 'count': '115'},
#     {'item': '-122.281937984', 'count': '115'}],
#    'smallest': '-122.337056283',
#    'not_null': '28363',
#    'sum': '-2696766.257984202135',
#    'cardinality': '3417'},
#   'format': {'precisionStyle': 'standard',
#    'rdf': 'http://www.w3.org/2003/01/geo/wgs84_pos#long',
#    'noCommas': 'false',
#    'align': 'right'}},
#  {'id': 404677357,
#   'name': 'Location 1 (city)',
#   'dataTypeName': 'text',
#   'fieldName': 'location_1_city',
#   'position': 8,
#   'renderTypeName': 'text',
#   'tableColumnId': 79600277,
#   'cachedContents': {'largest': 'Oakland',
#    'non_null': '7291',
#    'null': '47792',
#    'top': [{'item': 'Berkeley', 'count': '6897'},
#     {'item': 'Oakland', 'count': '334'},
#     {'item': 'Emeryville', 'count': '47'},
#     {'item': 'Albany', 'count': '12'},
#     {'item': 'C4', 'count': '1'}],
#    'smallest': 'Albany',
#    'cardinality': '5'},
#   'format': {}},
#  {'id': 404677358,
#   'name': 'Location 1 (state)',
#   'dataTypeName': 'text',
#   'fieldName': 'location_1_state',
#   'position': 9,
#   'renderTypeName': 'text',
#   'tableColumnId': 79600278,
#   'cachedContents': {'largest': 'CA',
#    'non_null': '8101',
#    'null': '46982',
#    'top': [{'item': 'CA', 'count': '8101'}],
#    'smallest': 'CA',
#    'cardinality': '1'},
#   'format': {}},
#  {'id': 404677356,
#   'name': 'Location 1 (zip)',
#   'dataTypeName': 'text',
#   'fieldName': 'location_1_zip',
#   'position': 10,
#   'renderTypeName': 'text',
#   'tableColumnId': 79600276,
#   'cachedContents': {'non_null': '0', 'null': '55083', 'cardinality': '0'},
#   'format': {}},
#  {'id': 404677362,
#   'name': 'Council Districts_uniq_prepend',
#   'dataTypeName': 'number',
#   'fieldName': ':@computed_region_b3wi_w8ix',
#   'position': 13,
#   'renderTypeName': 'number',
#   'tableColumnId': 79600282,
#   'format': {}},
#  {'id': 404677363,
#   'name': 'Council Districts_from_hg3u_n7v4',
#   'dataTypeName': 'number',
#   'fieldName': ':@computed_region_fhmw_rucx',
#   'position': 14,
#   'renderTypeName': 'number',
#   'tableColumnId': 79600283,
#   'format': {}},
#  {'id': 404677364,
#   'name': 'Council Districts_from_c8zs_8y7x',
#   'dataTypeName': 'number',
#   'fieldName': ':@computed_region_u3y2_d2ws',
#   'position': 15,
#   'renderTypeName': 'number',
#   'tableColumnId': 79600284,
#   'format': {}},
#  {'id': 404677365,
#   'name': 'Zip Codes',
#   'dataTypeName': 'number',
#   'fieldName': ':@computed_region_5s6d_2f32',
#   'position': 16,
#   'renderTypeName': 'number',
#   'tableColumnId': 79600285,
#   'format': {}},
#  {'id': 404677366,
#   'name': 'Police Beats',
#   'dataTypeName': 'number',
#   'fieldName': ':@computed_region_3ini_iehf',
#   'position': 17,
#   'renderTypeName': 'number',
#   'tableColumnId': 79600286,
#   'format': {}},
#  {'id': 404677367,
#   'name': 'Census Tracts',
#   'dataTypeName': 'number',
#   'fieldName': ':@computed_region_5bih_7r3y',
#   'position': 18,
#   'renderTypeName': 'number',
#   'tableColumnId': 79600287,
#   'format': {}},
#  {'id': 404677368,
#   'name': 'Council Districts',
#   'dataTypeName': 'number',
#   'fieldName': ':@computed_region_x3q3_gi3e',
#   'position': 19,
#   'renderTypeName': 'number',
#   'tableColumnId': 79600288,
#   'format': {}}]

# %% [markdown]
# We now have a list of records under `columns`. These are likely the column information.

# %%
stops_dict['meta']['view']['columns'][0]
# Out:
# {'id': -1,
#  'name': 'sid',
#  'dataTypeName': 'meta_data',
#  'fieldName': ':sid',
#  'position': 0,
#  'renderTypeName': 'meta_data',
#  'format': {},
#  'flags': ['hidden']}

# %%
stops_dict['meta']['view']['columns'][1]
# Out:
# {'id': -1,
#  'name': 'id',
#  'dataTypeName': 'meta_data',
#  'fieldName': ':id',
#  'position': 0,
#  'renderTypeName': 'meta_data',
#  'format': {},
#  'flags': ['hidden']}

# %% [markdown]
# The `name` attribute looks like something we need as the column names. The first one has name `sid`, the second one has name `id`. With these column information, and their corresponding data information from the top-most parent key `data`, we can create a dataframe:

# %%
stops = pd.DataFrame(
    stops_dict['data'],
    columns=[c['name'] for c in stops_dict['meta']['view']['columns']])

stops
# Out:
#                       sid                                    id  position  \
# 0      row-xkgf-zr8a.6fpe  00000000-0000-0000-4A5A-0E740119A894         0
# 1      row-6s6i~mhea-aiq2  00000000-0000-0000-2A6D-4576080468CA         0
# 2      row-zquh.a2sj_q4q3  00000000-0000-0000-97BB-D07AA3099E29         0
# 3      row-q5v4.77ck_hv59  00000000-0000-0000-BD2C-2D6B160554E3         0
# 4      row-3vse~wvru.ac54  00000000-0000-0000-E5B3-CFD85D4C4DD3         0
# ...                   ...                                   ...       ...
# 55078  row-sy64.ghqx_rmmr  00000000-0000-0000-EC97-D8A1B4A6965D         0
# 55079  row-8n9r~8ugp_uw97  00000000-0000-0000-CB6B-89AD079A47A5         0
# 55080  row-w54r-4ia6~egds  00000000-0000-0000-EF70-69613C269F63         0
# 55081  row-qyyc.nssz_cbpa  00000000-0000-0000-EF5C-C0AABF3969DB         0
# 55082  row-9hn6-qd3c_sajd  00000000-0000-0000-A58E-DD431BB6BC57         0
#
#        created_at created_meta  updated_at updated_meta meta Incident Number  \
# 0      1556687429         None  1556687433         None  { }   2019-00004289
# 1      1555712765         None  1555712773         None  { }            None
# 2      1556687429         None  1556687433         None  { }   2019-00016836
# 3      1556687429         None  1556687433         None  { }   2019-00014752
# 4      1556687429         None  1556687433         None  { }   2019-00011794
# ...           ...          ...         ...          ...  ...             ...
# 55078  1555712765         None  1555712783         None  { }   2018-00070395
# 55079  1555712765         None  1555712783         None  { }   2018-00049425
# 55080  1555712765         None  1555712783         None  { }   2018-00059477
# 55081  1555712765         None  1555712783         None  { }   2018-00069263
# 55082  1555712765         None  1555712783         None  { }   2018-00057917
#
#             Call Date/Time  ... Location 1 (city) Location 1 (state)  \
# 0      2019-01-25T14:51:35  ...              None               None
# 1      2017-08-07T07:18:25  ...              None               None
# 2      2019-03-29T21:37:10  ...              None               None
# 3      2019-03-19T19:00:51  ...              None               None
# 4      2019-03-05T16:24:38  ...              None               None
# ...                    ...  ...               ...                ...
# 55078  2018-12-21T17:02:17  ...              None               None
# 55079  2018-09-01T17:31:45  ...              None               None
# 55080  2018-10-22T22:23:36  ...              None               None
# 55081  2018-12-15T12:15:58  ...              None               None
# 55082  2018-10-15T00:32:03  ...              None               None
#
#       Location 1 (zip) Council Districts_uniq_prepend  \
# 0                 None                           None
# 1                 None                           None
# 2                 None                           None
# 3                 None                           None
# 4                 None                           None
# ...                ...                            ...
# 55078             None                           None
# 55079             None                           None
# 55080             None                           None
# 55081             None                           None
# 55082             None                           None
#
#       Council Districts_from_hg3u_n7v4 Council Districts_from_c8zs_8y7x  \
# 0                                 None                             None
# 1                                 None                             None
# 2                                 None                             None
# 3                                 None                             None
# 4                                 None                             None
# ...                                ...                              ...
# 55078                             None                             None
# 55079                             None                             None
# 55080                             None                             None
# 55081                             None                             None
# 55082                             None                             None
#
#       Zip Codes Police Beats Census Tracts Council Districts
# 0          None         None          None              None
# 1          None         None          None              None
# 2          None         None          None              None
# 3          None         None          None              None
# 4          None         None          None              None
# ...         ...          ...           ...               ...
# 55078      None         None          None              None
# 55079      None         None          None              None
# 55080      None         None          None              None
# 55081      None         None          None              None
# 55082      None         None          None              None
#
# [55083 rows x 26 columns]

# %%
# check!
stops.columns
# Out:
# Index(['sid', 'id', 'position', 'created_at', 'created_meta', 'updated_at',
#        'updated_meta', 'meta', 'Incident Number', 'Call Date/Time', 'Location',
#        'Incident Type', 'Dispositions', 'Location - Latitude',
#        'Location 1 (address)', 'Location - Longitude', 'Location 1 (city)',
#        'Location 1 (state)', 'Location 1 (zip)',
#        'Council Districts_uniq_prepend', 'Council Districts_from_hg3u_n7v4',
#        'Council Districts_from_c8zs_8y7x', 'Zip Codes', 'Police Beats',
#        'Census Tracts', 'Council Districts'],
#       dtype='object')

# %% [markdown]
# **Q3**: Following the examples in the *Calls* dataset in Part I, write some functions (for piping) to do the following:
# * The first 8 columns does not contain any useful information about the police stops. Drop them.
# * Clean the dispositions column by removing leading and trailing whitespaces, and the trailing semicolon

# %%
# complete the functions and then pipe them all
def drop_unwanted_cols(stops):
    # complete this function
    
def clean_dispositions(stops):
    # complete this function
    # hint: use strip() and rstrip() from pandas string functions
    
# finally, pipe the stops dataframe through the two cleaning functions defined above
